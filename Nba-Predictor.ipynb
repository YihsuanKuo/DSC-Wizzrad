# %%
import pandas as pd
import time
import requests
from nba_api.stats.static import players
from nba_api.stats.endpoints import commonplayerinfo
import os

def safe_request(api_call, retries=5, wait=2.0):
    for attempt in range(retries):
        try:
            return api_call()
        except Exception as e:
            print(f"Retry {attempt + 1} failed: {e}")
            if attempt < retries - 1:
                time.sleep(wait * (2 ** attempt))
            else:
                return None

# Load existing progress if it exists
bio_file = "player_bios.csv"
if os.path.exists(bio_file):
    existing_bios = pd.read_csv(bio_file)
    processed_ids = set(existing_bios['id'].values)
    data = existing_bios.to_dict('records')
else:
    processed_ids = set()
    data = []

all_players = players.get_active_players()

for i, player in enumerate(all_players):
    player_id = player['id']
    full_name = player['full_name']

    if player_id in processed_ids:
        continue

    info = safe_request(lambda: commonplayerinfo.CommonPlayerInfo(player_id=player_id))
    if info is None:
        print(f"Skipping {full_name} due to repeated errors.")
        continue

    info_df = info.get_data_frames()[0]

    if info_df.empty:
        print(f"No bio data for {full_name}")
        continue

    player_data = {
        'id': player_id,
        'full_name': full_name,
        'team': info_df.at[0, 'TEAM_NAME'] if 'TEAM_NAME' in info_df.columns else None,
        'position': info_df.at[0, 'POSITION'] if 'POSITION' in info_df.columns else None,
        'height': info_df.at[0, 'HEIGHT'] if 'HEIGHT' in info_df.columns else None,
        'weight': info_df.at[0, 'WEIGHT'] if 'WEIGHT' in info_df.columns else None,
        'college': info_df.at[0, 'COLLEGE'] if 'COLLEGE' in info_df.columns else None,
        'birthdate': info_df.at[0, 'BIRTHDATE'] if 'BIRTHDATE' in info_df.columns else None
    }

    data.append(player_data)
    processed_ids.add(player_id)

    if len(data) % 10 == 0:
        print(f"{len(data)} players collected so far (not saved to disk)")

    print(f"{i+1}/{len(all_players)}: Saved bio for {full_name}")
    time.sleep(3)  # Slow and safe

# Final save
df = pd.DataFrame(data)
print("Collection complete.")
# Out:
# 1/572: Saved bio for Precious Achiuwa
# 2/572: Saved bio for Steven Adams
# 3/572: Saved bio for Bam Adebayo
# 4/572: Saved bio for Ochai Agbaji
# 5/572: Saved bio for Santi Aldama
# 6/572: Saved bio for Trey Alexander
# 7/572: Saved bio for Nickeil Alexander-Walker
# 8/572: Saved bio for Grayson Allen
# 9/572: Saved bio for Jarrett Allen
# 10 players collected so far (not saved to disk)
# 10/572: Saved bio for Jose Alvarado
# 11/572: Saved bio for Kyle Anderson
# 12/572: Saved bio for Giannis Antetokounmpo
# 13/572: Saved bio for Cole Anthony
# 14/572: Saved bio for OG Anunoby
# 15/572: Saved bio for Taran Armstrong
# 16/572: Saved bio for Deni Avdija
# 17/572: Saved bio for Deandre Ayton
# 18/572: Saved bio for Marcus Bagley
# 19/572: Saved bio for Marvin Bagley III
# 20 players collected so far (not saved to disk)
# 20/572: Saved bio for Patrick Baldwin Jr.
# 21/572: Saved bio for LaMelo Ball
# 22/572: Saved bio for Lonzo Ball
# 23/572: Saved bio for Mo Bamba
# 24/572: Saved bio for Paolo Banchero
# 25/572: Saved bio for Desmond Bane
# 26/572: Saved bio for Dalano Banton
# 27/572: Saved bio for Dominick Barlow
# 28/572: Saved bio for Harrison Barnes
# 29/572: Saved bio for Scottie Barnes
# 30 players collected so far (not saved to disk)
# 30/572: Saved bio for RJ Barrett
# 31/572: Saved bio for Charles Bassey
# 32/572: Saved bio for Emoni Bates
# 33/572: Saved bio for Jamison Battle
# 34/572: Saved bio for Nicolas Batum
# 35/572: Saved bio for Damion Baugh
# 36/572: Saved bio for Bradley Beal
# 37/572: Saved bio for Malik Beasley
# 38/572: Saved bio for MarJon Beauchamp
# 39/572: Saved bio for Reece Beekman
# 40 players collected so far (not saved to disk)
# 40/572: Saved bio for Saddiq Bey
# 41/572: Saved bio for Goga Bitadze
# 42/572: Saved bio for Bismack Biyombo
# 43/572: Saved bio for Anthony Black
# 44/572: Saved bio for Bogdan Bogdanović
# 45/572: Saved bio for Bol Bol
# 46/572: Saved bio for Adem Bona
# 47/572: Saved bio for Devin Booker
# 48/572: Saved bio for Brandon Boston
# 49/572: Saved bio for Chris Boucher
# 50 players collected so far (not saved to disk)
# 50/572: Saved bio for Jamaree Bouyea
# 51/572: Saved bio for Tony Bradley
# 52/572: Saved bio for Malaki Branham
# 53/572: Saved bio for Christian Braun
# 54/572: Saved bio for Jalen Bridges
# 55/572: Saved bio for Mikal Bridges
# 56/572: Saved bio for Miles Bridges
# 57/572: Saved bio for Oshae Brissett
# 58/572: Saved bio for Malcolm Brogdon
# 59/572: Saved bio for Dillon Brooks
# 60 players collected so far (not saved to disk)
# 60/572: Saved bio for Keion Brooks Jr.
# 61/572: Saved bio for Bruce Brown
# 62/572: Saved bio for Jaylen Brown
# 63/572: Saved bio for Kobe Brown
# 64/572: Saved bio for Moses Brown
# 65/572: Saved bio for Jalen Brunson
# 66/572: Saved bio for Thomas Bryant
# 67/572: Saved bio for Kobe Bufkin
# 68/572: Saved bio for Alec Burks
# 69/572: Saved bio for Jared Butler
# 70 players collected so far (not saved to disk)
# 70/572: Saved bio for Jimmy Butler III
# 71/572: Saved bio for Matas Buzelis
# 72/572: Saved bio for Jamal Cain
# 73/572: Saved bio for Kentavious Caldwell-Pope
# 74/572: Saved bio for Toumani Camara
# 75/572: Saved bio for Clint Capela
# 76/572: Saved bio for Branden Carlson
# 77/572: Saved bio for Bub Carrington
# 78/572: Saved bio for Devin Carter
# 79/572: Saved bio for Jevon Carter
# 80 players collected so far (not saved to disk)
# 80/572: Saved bio for Wendell Carter Jr.
# 81/572: Saved bio for D.J. Carton
# 82/572: Saved bio for Alex Caruso
# 83/572: Saved bio for Stephon Castle
# 84/572: Saved bio for Colin Castleton
# 85/572: Saved bio for Julian Champagnie
# 86/572: Saved bio for Justin Champagnie
# 87/572: Saved bio for Ulrich Chomche
# 88/572: Saved bio for Cam Christie
# 89/572: Saved bio for Max Christie
# 90 players collected so far (not saved to disk)
# 90/572: Saved bio for Josh Christopher
# 91/572: Saved bio for Sidy Cissoko
# 92/572: Saved bio for Jaylen Clark
# 93/572: Saved bio for Brandon Clarke
# 94/572: Saved bio for Jordan Clarkson
# 95/572: Saved bio for Nic Claxton
# 96/572: Saved bio for Donovan Clingan
# 97/572: Saved bio for Noah Clowney
# 98/572: Saved bio for Amir Coffey
# 99/572: Saved bio for Isaiah Collier
# 100 players collected so far (not saved to disk)
# 100/572: Saved bio for John Collins
# 101/572: Saved bio for Yuri Collins
# 102/572: Saved bio for Zach Collins
# 103/572: Saved bio for Mike Conley
# 104/572: Saved bio for Pat Connaughton
# 105/572: Saved bio for Bilal Coulibaly
# 106/572: Saved bio for Ricky Council IV
# 107/572: Saved bio for Torrey Craig
# 108/572: Saved bio for Isaiah Crawford
# 109/572: Saved bio for Jae Crowder
# 110 players collected so far (not saved to disk)
# 110/572: Saved bio for Cade Cunningham
# 111/572: Saved bio for Seth Curry
# 112/572: Saved bio for Stephen Curry
# 113/572: Saved bio for Pacome Dadiet
# 114/572: Saved bio for Dyson Daniels
# 115/572: Saved bio for N'Faly Dante
# 116/572: Saved bio for Anthony Davis
# 117/572: Saved bio for Johnny Davis
# 118/572: Saved bio for JD Davison
# 119/572: Saved bio for DeMar DeRozan
# 120 players collected so far (not saved to disk)
# 120/572: Saved bio for RayJ Dennis
# 121/572: Saved bio for Donte DiVincenzo
# 122/572: Saved bio for Moussa Diabaté
# 123/572: Saved bio for Gradey Dick
# 124/572: Saved bio for Ousmane Dieng
# 125/572: Saved bio for Rob Dillingham
# 126/572: Saved bio for Spencer Dinwiddie
# 127/572: Saved bio for Luka Dončić
# 128/572: Saved bio for Luguentz Dort
# 129/572: Saved bio for Ayo Dosunmu
# 130 players collected so far (not saved to disk)
# 130/572: Saved bio for Jeff Dowtin Jr.
# 131/572: Saved bio for PJ Dozier
# 132/572: Saved bio for Andre Drummond
# 133/572: Saved bio for Chris Duarte
# 134/572: Saved bio for Alex Ducas
# 135/572: Saved bio for David Duke Jr.
# 136/572: Saved bio for Kris Dunn
# 137/572: Saved bio for Ryan Dunn
# 138/572: Saved bio for Kevin Durant
# 139/572: Saved bio for Jalen Duren
# 140 players collected so far (not saved to disk)
# 140/572: Saved bio for Tari Eason
# 141/572: Saved bio for Zach Edey
# 142/572: Saved bio for Anthony Edwards
# 143/572: Saved bio for Jesse Edwards
# 144/572: Saved bio for Justin Edwards
# 145/572: Saved bio for Kessler Edwards
# 146/572: Saved bio for Keon Ellis
# 147/572: Saved bio for Joel Embiid
# 148/572: Saved bio for Tyson Etienne
# 149/572: Saved bio for Drew Eubanks
# 150 players collected so far (not saved to disk)
# 150/572: Saved bio for Tosan Evbuomwan
# 151/572: Saved bio for Danté Exum
# 152/572: Saved bio for Bruno Fernando
# 153/572: Saved bio for Kyle Filipowski
# 154/572: Saved bio for Dorian Finney-Smith
# 155/572: Saved bio for Adam Flagler
# 156/572: Saved bio for Trentyn Flowers
# 157/572: Saved bio for Malachi Flynn
# 158/572: Saved bio for Simone Fontecchio
# 159/572: Saved bio for De'Aaron Fox
# 160 players collected so far (not saved to disk)
# 160/572: Saved bio for Enrique Freeman
# 161/572: Saved bio for Markelle Fultz
# 162/572: Saved bio for Johnny Furphy
# 163/572: Saved bio for Daniel Gafford
# 164/572: Saved bio for Darius Garland
# 165/572: Saved bio for Marcus Garrett
# 166/572: Saved bio for Luka Garza
# 167/572: Saved bio for Keyonte George
# 168/572: Saved bio for Kyshawn George
# 169/572: Saved bio for Paul George
# 170 players collected so far (not saved to disk)
# 170/572: Saved bio for Taj Gibson
# 171/572: Saved bio for Josh Giddey
# 172/572: Saved bio for Shai Gilgeous-Alexander
# 173/572: Saved bio for Anthony Gill
# 174/572: Saved bio for Collin Gillespie
# 175/572: Saved bio for Rudy Gobert
# 176/572: Saved bio for Jordan Goodwin
# 177/572: Saved bio for Aaron Gordon
# 178/572: Saved bio for Eric Gordon
# 179/572: Saved bio for Jazian Gortman
# 180 players collected so far (not saved to disk)
# 180/572: Saved bio for Jerami Grant
# 181/572: Saved bio for AJ Green
# 182/572: Saved bio for Draymond Green
# 183/572: Saved bio for Jalen Green
# 184/572: Saved bio for Javonte Green
# 185/572: Saved bio for Jeff Green
# 186/572: Saved bio for Josh Green
# 187/572: Saved bio for Quentin Grimes
# 188/572: Saved bio for Mouhamed Gueye
# 189/572: Saved bio for Rui Hachimura
# 190 players collected so far (not saved to disk)
# 190/572: Saved bio for Tyrese Haliburton
# 191/572: Saved bio for PJ Hall
# 192/572: Saved bio for Tim Hardaway Jr.
# 193/572: Saved bio for James Harden
# 194/572: Saved bio for Jaden Hardy
# 195/572: Saved bio for Elijah Harkless
# 196/572: Saved bio for Ron Harper Jr.
# 197/572: Saved bio for Gary Harris
# 198/572: Saved bio for Tobias Harris
# 199/572: Saved bio for Josh Hart
# 200 players collected so far (not saved to disk)
# 200/572: Saved bio for Isaiah Hartenstein
# 201/572: Saved bio for Sam Hauser
# 202/572: Saved bio for Jordan Hawkins
# 203/572: Saved bio for Jaxson Hayes
# 204/572: Saved bio for Killian Hayes
# 205/572: Saved bio for Scoot Henderson
# 206/572: Saved bio for Taylor Hendricks
# 207/572: Saved bio for Tyler Herro
# 208/572: Saved bio for Buddy Hield
# 209/572: Saved bio for Haywood Highsmith
# 210 players collected so far (not saved to disk)
# 210/572: Saved bio for Aaron Holiday
# 211/572: Saved bio for Jrue Holiday
# 212/572: Saved bio for Ronald Holland II
# 213/572: Saved bio for Richaun Holmes
# 214/572: Saved bio for DaRon Holmes II
# 215/572: Saved bio for Chet Holmgren
# 216/572: Saved bio for Jalen Hood-Schifino
# 217/572: Saved bio for Al Horford
# 218/572: Saved bio for Talen Horton-Tucker
# 219/572: Saved bio for Caleb Houstan
# 220 players collected so far (not saved to disk)
# 220/572: Saved bio for Jett Howard
# 221/572: Saved bio for Kevin Huerter
# 222/572: Saved bio for Jay Huff
# 223/572: Saved bio for Ariel Hukporti
# 224/572: Saved bio for De'Andre Hunter
# 225/572: Saved bio for Bones Hyland
# 226/572: Saved bio for Oso Ighodaro
# 227/572: Saved bio for Joe Ingles
# 228/572: Saved bio for Brandon Ingram
# 229/572: Saved bio for Harrison Ingram
# 230 players collected so far (not saved to disk)
# 230/572: Saved bio for Kyrie Irving
# 231/572: Saved bio for Jonathan Isaac
# 232/572: Saved bio for Jaden Ivey
# 233/572: Saved bio for GG Jackson
# 234/572: Saved bio for Isaiah Jackson
# 235/572: Saved bio for Quenton Jackson
# 236/572: Saved bio for Reggie Jackson
# 237/572: Saved bio for Andre Jackson Jr.
# 238/572: Saved bio for Jaren Jackson Jr.
# 239/572: Saved bio for Trayce Jackson-Davis
# 240 players collected so far (not saved to disk)
# 240/572: Saved bio for Bronny James
# 241/572: Saved bio for LeBron James
# 242/572: Saved bio for Jaime Jaquez Jr.
# 243/572: Saved bio for DaQuan Jeffries
# 244/572: Saved bio for Trey Jemison III
# 245/572: Saved bio for Daniss Jenkins
# 246/572: Saved bio for Ty Jerome
# 247/572: Saved bio for Isaiah Joe
# 248/572: Saved bio for AJ Johnson
# 249/572: Saved bio for Cameron Johnson
# 250 players collected so far (not saved to disk)
# 250/572: Saved bio for Jalen Johnson
# 251/572: Saved bio for James Johnson
# 252/572: Saved bio for Keldon Johnson
# 253/572: Saved bio for Keon Johnson
# 254/572: Saved bio for Keshad Johnson
# 255/572: Saved bio for Nikola Jokić
# 256/572: Saved bio for Colby Jones
# 257/572: Saved bio for Dillon Jones
# 258/572: Saved bio for Herbert Jones
# 259/572: Saved bio for Isaac Jones
# 260 players collected so far (not saved to disk)
# 260/572: Saved bio for Kai Jones
# 261/572: Saved bio for Mason Jones
# 262/572: Saved bio for Spencer Jones
# 263/572: Saved bio for Tre Jones
# 264/572: Saved bio for Tyus Jones
# 265/572: Saved bio for Derrick Jones Jr.
# 266/572: Saved bio for DeAndre Jordan
# 267/572: Saved bio for Cory Joseph
# 268/572: Saved bio for Nikola Jović
# 269/572: Saved bio for Johnny Juzang
# 270 players collected so far (not saved to disk)
# 270/572: Saved bio for Yuki Kawamura
# 271/572: Saved bio for Kylor Kelley
# 272/572: Saved bio for Luke Kennard
# 273/572: Saved bio for Walker Kessler
# 274/572: Saved bio for Braxton Key
# 275/572: Saved bio for Corey Kispert
# 276/572: Saved bio for Maxi Kleber
# 277/572: Saved bio for Bobi Klintman
# 278/572: Saved bio for Dalton Knecht
# 279/572: Saved bio for Kevin Knox II
# 280 players collected so far (not saved to disk)
# 280/572: Saved bio for Tyler Kolek
# 281/572: Saved bio for Christian Koloko
# 282/572: Saved bio for John Konchar
# 283/572: Saved bio for Luke Kornet
# 284/572: Saved bio for Vít Krejčí
# 285/572: Saved bio for Jonathan Kuminga
# 286/572: Saved bio for Kyle Kuzma
# 287/572: Saved bio for Jake LaRavia
# 288/572: Saved bio for Zach LaVine
# 289/572: Saved bio for Skal Labissiere
# 290 players collected so far (not saved to disk)
# 290/572: Saved bio for Jock Landale
# 291/572: Saved bio for Pelle Larsson
# 292/572: Saved bio for A.J. Lawson
# 293/572: Saved bio for Caris LeVert
# 294/572: Saved bio for Damion Lee
# 295/572: Saved bio for Alex Len
# 296/572: Saved bio for Kawhi Leonard
# 297/572: Saved bio for Malevy Leons
# 298/572: Saved bio for Maxwell Lewis
# 299/572: Saved bio for E.J. Liddell
# 300 players collected so far (not saved to disk)
# 300/572: Saved bio for Damian Lillard
# 301/572: Saved bio for Dereck Lively II
# 302/572: Saved bio for Chris Livingston
# 303/572: Saved bio for Kevon Looney
# 304/572: Saved bio for Brook Lopez
# 305/572: Saved bio for Kevin Love
# 306/572: Saved bio for Kyle Lowry
# 307/572: Saved bio for Seth Lundy
# 308/572: Saved bio for Trey Lyles
# 309/572: Saved bio for Sandro Mamukelashvili
# 310 players collected so far (not saved to disk)
# 310/572: Saved bio for Terance Mann
# 311/572: Saved bio for Tre Mann
# 312/572: Saved bio for Lauri Markkanen
# 313/572: Saved bio for Naji Marshall
# 314/572: Saved bio for Caleb Martin
# 315/572: Saved bio for Cody Martin
# 316/572: Saved bio for Jaylen Martin
# 317/572: Saved bio for KJ Martin
# 318/572: Saved bio for Tyrese Martin
# 319/572: Saved bio for Garrison Mathews
# 320 players collected so far (not saved to disk)
# 320/572: Saved bio for Bennedict Mathurin
# 321/572: Saved bio for Karlo Matković
# 322/572: Saved bio for Tyrese Maxey
# 323/572: Saved bio for Miles McBride
# 324/572: Saved bio for Jared McCain
# 325/572: Saved bio for Mac McClung
# 326/572: Saved bio for CJ McCollum
# 327/572: Saved bio for T.J. McConnell
# 328/572: Saved bio for Kevin McCullar Jr.
# 329/572: Saved bio for Jaden McDaniels
# 330 players collected so far (not saved to disk)
# 330/572: Saved bio for Jalen McDaniels
# 331/572: Saved bio for Doug McDermott
# 332/572: Saved bio for Bryce McGowens
# 333/572: Saved bio for Jordan McLaughlin
# 334/572: Saved bio for Jack McVeigh
# 335/572: Saved bio for De'Anthony Melton
# 336/572: Saved bio for Sam Merrill
# 337/572: Saved bio for Vasilije Micić
# 338/572: Saved bio for Khris Middleton
# 339/572: Saved bio for Brandon Miller
# 340 players collected so far (not saved to disk)
# 340/572: Saved bio for Emanuel Miller
# 341/572: Saved bio for Jordan Miller
# 342/572: Saved bio for Leonard Miller
# 343/572: Saved bio for Patty Mills
# 344/572: Saved bio for Shake Milton
# 345/572: Saved bio for Justin Minaya
# 346/572: Saved bio for Riley Minix
# 347/572: Saved bio for Josh Minott
# 348/572: Saved bio for Yves Missi
# 349/572: Saved bio for Ajay Mitchell
# 350 players collected so far (not saved to disk)
# 350/572: Saved bio for Davion Mitchell
# 351/572: Saved bio for Donovan Mitchell
# 352/572: Saved bio for Evan Mobley
# 353/572: Saved bio for Jonathan Mogbo
# 354/572: Saved bio for Malik Monk
# 355/572: Saved bio for Moses Moody
# 356/572: Saved bio for Tazé Moore
# 357/572: Saved bio for Wendell Moore Jr.
# 358/572: Saved bio for Ja Morant
# 359/572: Saved bio for Markieff Morris
# 360 players collected so far (not saved to disk)
# 360/572: Saved bio for Monté Morris
# 361/572: Saved bio for Trey Murphy III
# 362/572: Saved bio for Dejounte Murray
# 363/572: Saved bio for Jamal Murray
# 364/572: Saved bio for Keegan Murray
# 365/572: Saved bio for Kris Murray
# 366/572: Saved bio for Svi Mykhailiuk
# 367/572: Saved bio for Pete Nance
# 368/572: Saved bio for Larry Nance Jr.
# 369/572: Saved bio for Andrew Nembhard
# 370 players collected so far (not saved to disk)
# 370/572: Saved bio for Aaron Nesmith
# 371/572: Saved bio for Tristen Newton
# 372/572: Saved bio for Georges Niang
# 373/572: Saved bio for Daishen Nix
# 374/572: Saved bio for Zeke Nnaji
# 375/572: Saved bio for Miles Norris
# 376/572: Saved bio for Jaylen Nowell
# 377/572: Saved bio for Jusuf Nurkić
# 378/572: Saved bio for Royce O'Neale
# 379/572: Saved bio for Jahlil Okafor
# 380 players collected so far (not saved to disk)
# 380/572: Saved bio for Chuma Okeke
# 381/572: Saved bio for Josh Okogie
# 382/572: Saved bio for Onyeka Okongwu
# 383/572: Saved bio for Isaac Okoro
# 384/572: Saved bio for Quincy Olivari
# 385/572: Saved bio for Kelly Olynyk
# 386/572: Saved bio for Kelly Oubre Jr.
# 387/572: Saved bio for Chris Paul
# 388/572: Saved bio for Cameron Payne
# 389/572: Saved bio for Elfrid Payton
# 390 players collected so far (not saved to disk)
# 390/572: Saved bio for Gary Payton II
# 391/572: Saved bio for Drew Peterson
# 392/572: Saved bio for Julian Phillips
# 393/572: Saved bio for Jalen Pickett
# 394/572: Saved bio for Scotty Pippen Jr.
# 395/572: Saved bio for Daeqwon Plowden
# 396/572: Saved bio for Mason Plumlee
# 397/572: Saved bio for Brandin Podziemski
# 398/572: Saved bio for Jakob Poeltl
# 399/572: Saved bio for Jordan Poole
# 400 players collected so far (not saved to disk)
# 400/572: Saved bio for Craig Porter Jr.
# 401/572: Saved bio for Kevin Porter Jr.
# 402/572: Saved bio for Michael Porter Jr.
# 403/572: Saved bio for Bobby Portis
# 404/572: Saved bio for Kristaps Porziņģis
# 405/572: Saved bio for Quinten Post
# 406/572: Saved bio for Micah Potter
# 407/572: Saved bio for Dwight Powell
# 408/572: Saved bio for Norman Powell
# 409/572: Saved bio for Taurean Prince
# 410 players collected so far (not saved to disk)
# 410/572: Saved bio for Payton Pritchard
# 411/572: Saved bio for Olivier-Maxence Prosper
# 412/572: Saved bio for Zyon Pullin
# 413/572: Saved bio for Trevelin Queen
# 414/572: Saved bio for Neemias Queta
# 415/572: Saved bio for Immanuel Quickley
# 416/572: Saved bio for Lester Quinones
# 417/572: Saved bio for Julius Randle
# 418/572: Saved bio for Duop Reath
# 419/572: Saved bio for Austin Reaves
# 420 players collected so far (not saved to disk)
# 420/572: Saved bio for Cam Reddish
# 421/572: Saved bio for Paul Reed
# 422/572: Saved bio for Alex Reese
# 423/572: Saved bio for Antonio Reeves
# 424/572: Saved bio for Naz Reid
# 425/572: Saved bio for Jared Rhoden
# 426/572: Saved bio for Nick Richards
# 427/572: Saved bio for Josh Richardson
# 428/572: Saved bio for Zaccharie Risacher
# 429/572: Saved bio for Liam Robbins
# 430 players collected so far (not saved to disk)
# 430/572: Saved bio for Duncan Robinson
# 431/572: Saved bio for Mitchell Robinson
# 432/572: Saved bio for Orlando Robinson
# 433/572: Saved bio for Jeremiah Robinson-Earl
# 434/572: Saved bio for David Roddy
# 435/572: Saved bio for Ryan Rollins
# 436/572: Saved bio for Jackson Rowe
# 437/572: Saved bio for Terry Rozier
# 438/572: Saved bio for Rayan Rupert
# 439/572: Saved bio for D'Angelo Russell
# 440 players collected so far (not saved to disk)
# 440/572: Saved bio for Matt Ryan
# 441/572: Saved bio for Domantas Sabonis
# 442/572: Saved bio for Tidjane Salaün
# 443/572: Saved bio for Adama Sanogo
# 444/572: Saved bio for Gui Santos
# 445/572: Saved bio for Alex Sarr
# 446/572: Saved bio for Marcus Sasser
# 447/572: Saved bio for Baylor Scheierman
# 448/572: Saved bio for Dennis Schröder
# 449/572: Saved bio for Alperen Sengun
# 450 players collected so far (not saved to disk)
# 450/572: Saved bio for Brice Sensabaugh
# 451/572: Saved bio for Collin Sexton
# 452/572: Saved bio for Landry Shamet
# 453/572: Saved bio for Terrence Shannon Jr.
# 454/572: Saved bio for Day'Ron Sharpe
# 455/572: Saved bio for Shaedon Sharpe
# 456/572: Saved bio for Jamal Shead
# 457/572: Saved bio for Ben Sheppard
# 458/572: Saved bio for Reed Sheppard
# 459/572: Saved bio for Pascal Siakam
# 460 players collected so far (not saved to disk)
# 460/572: Saved bio for Ben Simmons
# 461/572: Saved bio for Anfernee Simons
# 462/572: Saved bio for KJ Simpson
# 463/572: Saved bio for Jericho Sims
# 464/572: Saved bio for Marcus Smart
# 465/572: Saved bio for Dru Smith
# 466/572: Saved bio for Jalen Smith
# 467/572: Saved bio for Tolu Smith
# 468/572: Saved bio for Tyler Smith
# 469/572: Saved bio for Jabari Smith Jr.
# 470 players collected so far (not saved to disk)
# 470/572: Saved bio for Nick Smith Jr.
# 471/572: Saved bio for Jeremy Sochan
# 472/572: Saved bio for Cam Spencer
# 473/572: Saved bio for Pat Spencer
# 474/572: Saved bio for Jaden Springer
# 475/572: Saved bio for Isaiah Stevens
# 476/572: Saved bio for Lamar Stevens
# 477/572: Saved bio for Isaiah Stewart
# 478/572: Saved bio for Julian Strawther
# 479/572: Saved bio for Max Strus
# 480 players collected so far (not saved to disk)
# 480/572: Saved bio for Jalen Suggs
# 481/572: Saved bio for Cole Swider
# 482/572: Saved bio for Jae'Sean Tate
# 483/572: Saved bio for Jayson Tatum
# 484/572: Saved bio for Terry Taylor
# 485/572: Saved bio for Garrett Temple
# 486/572: Saved bio for Dalen Terry
# 487/572: Saved bio for Daniel Theis
# 488/572: Saved bio for Cam Thomas
# 489/572: Saved bio for Amen Thompson
# 490 players collected so far (not saved to disk)
# 490/572: Saved bio for Ausar Thompson
# 491/572: Saved bio for Ethan Thompson
# 492/572: Saved bio for Klay Thompson
# 493/572: Saved bio for Tristan Thompson
# 494/572: Saved bio for JT Thor
# 495/572: Saved bio for Matisse Thybulle
# 496/572: Saved bio for Xavier Tillman
# 497/572: Saved bio for Drew Timme
# 498/572: Saved bio for Nae'Qwan Tomlin
# 499/572: Saved bio for Nikola Topić
# 500 players collected so far (not saved to disk)
# 500/572: Saved bio for Jacob Toppin
# 501/572: Saved bio for Obi Toppin
# 502/572: Saved bio for Karl-Anthony Towns
# 503/572: Saved bio for Armel Traoré
# 504/572: Saved bio for Luke Travers
# 505/572: Saved bio for Gary Trent Jr.
# 506/572: Saved bio for Oscar Tshiebwe
# 507/572: Saved bio for P.J. Tucker
# 508/572: Saved bio for Myles Turner
# 509/572: Saved bio for Hunter Tyson
# 510 players collected so far (not saved to disk)
# 510/572: Saved bio for Jaylon Tyson
# 511/572: Saved bio for Stanley Umude
# 512/572: Saved bio for Jonas Valančiūnas
# 513/572: Saved bio for Fred VanVleet
# 514/572: Saved bio for Jarred Vanderbilt
# 515/572: Saved bio for Devin Vassell
# 516/572: Saved bio for Gabe Vincent
# 517/572: Saved bio for Tristan Vukcevic
# 518/572: Saved bio for Nikola Vučević
# 519/572: Saved bio for Dean Wade
# 520 players collected so far (not saved to disk)
# 520/572: Saved bio for Franz Wagner
# 521/572: Saved bio for Moritz Wagner
# 522/572: Saved bio for Jabari Walker
# 523/572: Saved bio for Jarace Walker
# 524/572: Saved bio for Lonnie Walker IV
# 525/572: Saved bio for Cason Wallace
# 526/572: Saved bio for Keaton Wallace
# 527/572: Saved bio for Jordan Walsh
# 528/572: Saved bio for Ja'Kobe Walter
# 529/572: Saved bio for Kel'el Ware
# 530 players collected so far (not saved to disk)
# 530/572: Saved bio for P.J. Washington
# 531/572: Saved bio for TyTy Washington Jr.
# 532/572: Saved bio for Lindy Waters III
# 533/572: Saved bio for Trendon Watford
# 534/572: Saved bio for Anton Watson
# 535/572: Saved bio for Peyton Watson
# 536/572: Saved bio for Jaylen Wells
# 537/572: Saved bio for Victor Wembanyama
# 538/572: Saved bio for Blake Wesley
# 539/572: Saved bio for Russell Westbrook
# 540 players collected so far (not saved to disk)
# 540/572: Saved bio for Phillip Wheeler
# 541/572: Saved bio for Coby White
# 542/572: Saved bio for Derrick White
# 543/572: Saved bio for Dariq Whitehead
# 544/572: Saved bio for Cam Whitmore
# 545/572: Saved bio for Aaron Wiggins
# 546/572: Saved bio for Andrew Wiggins
# 547/572: Saved bio for Alondes Williams
# 548/572: Saved bio for Brandon Williams
# 549/572: Saved bio for Cody Williams
# 550 players collected so far (not saved to disk)
# 550/572: Saved bio for Grant Williams
# 551/572: Saved bio for Jalen Williams
# 552/572: Saved bio for Jaylin Williams
# 553/572: Saved bio for Kenrich Williams
# 554/572: Saved bio for Mark Williams
# 555/572: Saved bio for Nate Williams
# 556/572: Saved bio for Patrick Williams
# 557/572: Saved bio for Ziaire Williams
# 558/572: Saved bio for Robert Williams III
# 559/572: Saved bio for Vince Williams Jr.
# 560 players collected so far (not saved to disk)
# 560/572: Saved bio for Zion Williamson
# 561/572: Saved bio for Jalen Wilson
# 562/572: Saved bio for James Wiseman
# 563/572: Saved bio for Isaiah Wong
# 564/572: Saved bio for Delon Wright
# 565/572: Saved bio for Guerschon Yabusele
# 566/572: Saved bio for Cui Yongxi
# 567/572: Saved bio for Jahmir Young
# 568/572: Saved bio for Trae Young
# 569/572: Saved bio for Ivica Zubac
# 570 players collected so far (not saved to disk)
# 570/572: Saved bio for Tristan da Silva
# 571/572: Saved bio for Vlatko Čančar
# 572/572: Saved bio for Dario Šarić
# Collection complete.

# %%
df
# Out:
#      Unnamed: 0         full_name       team position  height  weight  age  \
# 0             0  Precious Achiuwa     Knicks        F  203.20   243.0   25
# 1             1      Steven Adams    Rockets        C  210.82   265.0   31
# 2             2       Bam Adebayo       Heat      F-C  205.74   255.0   27
# 3             3      Ochai Agbaji    Raptors        G  195.58   215.0   24
# 4             4      Santi Aldama  Grizzlies      F-C  213.36   215.0   24
# ..          ...               ...        ...      ...     ...     ...  ...
# 567         567        Trae Young      Hawks        G  185.42   164.0   26
# 568         568       Ivica Zubac   Clippers        C  213.36   240.0   28
# 569         569  Tristan da Silva      Magic        F  203.20   217.0   23
# 570         570     Vlatko Čančar    Nuggets        F  203.20   236.0   27
# 571         571       Dario Šarić    Nuggets      F-C  208.28   225.0   30
#
#           region  average_points  average_assists  average_rebounds  \
# 0        Nigeria        6.351852         0.925926          5.407407
# 1    New Zealand        3.910714         1.142857          5.589286
# 2            USA       17.840000         4.333333          9.586667
# 3            USA       10.065574         1.557377          3.786885
# 4          Spain       12.754098         2.868852          6.573770
# ..           ...             ...              ...               ...
# 567          USA       24.027778        11.555556          3.138889
# 568      Croatia       16.426667         2.586667         12.546667
# 569      Germany        7.042254         1.464789          3.267606
# 570     Slovenia        1.846154         0.692308          2.461538
# 571      Croatia        3.500000         1.437500          3.125000
#
#      average_steals  average_blocks  \
# 0          0.759259        0.703704
# 1          0.392857        0.464286
# 2          1.240000        0.693333
# 3          0.803279        0.475410
# 4          0.786885        0.475410
# ..              ...             ...
# 567        1.194444        0.152778
# 568        0.693333        1.173333
# 569        0.422535        0.225352
# 570        0.230769        0.153846
# 571        0.437500        0.062500
#
#                                                 awards conference  \
# 0                                                            East
# 1                                      All-Rookie Team       West
# 2    All-Defensive Team; All-Defensive Team; All-De...       East
# 3                                                            East
# 4                                                            West
# ..                                                 ...        ...
# 567  All-NBA; All-Rookie Team; NBA All-Star; NBA Al...       East
# 568                                                          West
# 569                                                          East
# 570                                       NBA Champion       West
# 571  All-Rookie Team; NBA Rookie of the Month; NBA ...       West
#
#      awards_count
# 0               0
# 1               1
# 2               1
# 3               0
# 4               0
# ..            ...
# 567             1
# 568             0
# 569             0
# 570             1
# 571             1
#
# [572 rows x 16 columns]

# %%
df
# Out:
#      Unnamed: 0         full_name       team position  height  weight  age  \
# 0             0  Precious Achiuwa     Knicks        F  203.20   243.0   25
# 1             1      Steven Adams    Rockets        C  210.82   265.0   31
# 2             2       Bam Adebayo       Heat      F-C  205.74   255.0   27
# 3             3      Ochai Agbaji    Raptors        G  195.58   215.0   24
# 4             4      Santi Aldama  Grizzlies      F-C  213.36   215.0   24
# ..          ...               ...        ...      ...     ...     ...  ...
# 567         567        Trae Young      Hawks        G  185.42   164.0   26
# 568         568       Ivica Zubac   Clippers        C  213.36   240.0   28
# 569         569  Tristan da Silva      Magic        F  203.20   217.0   23
# 570         570     Vlatko Čančar    Nuggets        F  203.20   236.0   27
# 571         571       Dario Šarić    Nuggets      F-C  208.28   225.0   30
#
#           region  average_points  average_assists  average_rebounds  \
# 0        Nigeria        6.351852         0.925926          5.407407
# 1    New Zealand        3.910714         1.142857          5.589286
# 2            USA       17.840000         4.333333          9.586667
# 3            USA       10.065574         1.557377          3.786885
# 4          Spain       12.754098         2.868852          6.573770
# ..           ...             ...              ...               ...
# 567          USA       24.027778        11.555556          3.138889
# 568      Croatia       16.426667         2.586667         12.546667
# 569      Germany        7.042254         1.464789          3.267606
# 570     Slovenia        1.846154         0.692308          2.461538
# 571      Croatia        3.500000         1.437500          3.125000
#
#      average_steals  average_blocks  \
# 0          0.759259        0.703704
# 1          0.392857        0.464286
# 2          1.240000        0.693333
# 3          0.803279        0.475410
# 4          0.786885        0.475410
# ..              ...             ...
# 567        1.194444        0.152778
# 568        0.693333        1.173333
# 569        0.422535        0.225352
# 570        0.230769        0.153846
# 571        0.437500        0.062500
#
#                                                 awards conference  \
# 0                                                            East
# 1                                      All-Rookie Team       West
# 2    All-Defensive Team; All-Defensive Team; All-De...       East
# 3                                                            East
# 4                                                            West
# ..                                                 ...        ...
# 567  All-NBA; All-Rookie Team; NBA All-Star; NBA Al...       East
# 568                                                          West
# 569                                                          East
# 570                                       NBA Champion       West
# 571  All-Rookie Team; NBA Rookie of the Month; NBA ...       West
#
#      awards_count
# 0               0
# 1               1
# 2               1
# 3               0
# 4               0
# ..            ...
# 567             1
# 568             0
# 569             0
# 570             1
# 571             1
#
# [572 rows x 16 columns]

# %%
import pandas as pd
import time
import datetime
import os
from nba_api.stats.static import players
from nba_api.stats.endpoints import commonplayerinfo, playercareerstats, playerawards

# Add custom headers to avoid being blocked
custom_headers = {
    'User-Agent': 'Mozilla/5.0',
    'Referer': 'https://www.nba.com/',
    'Origin': 'https://www.nba.com'
}

def safe_request(api_call, retries=5, wait=2.0):
    for attempt in range(retries):
        try:
            return api_call()
        except Exception as e:
            print(f"Retry {attempt + 1} failed: {e}")
            if attempt < retries - 1:
                time.sleep(wait * (2 ** attempt))
            else:
                return None

def calculate_age(birthdate_str):
    if pd.isna(birthdate_str):
        return None
    try:
        # Handle format like '1999-09-19T00:00:00'
        birthdate = datetime.datetime.strptime(birthdate_str.split("T")[0], "%Y-%m-%d")
        today = datetime.datetime.today()
        return today.year - birthdate.year - ((today.month, today.day) < (birthdate.month, birthdate.day))
    except Exception as e:
        print(f"Failed to parse birthdate: {birthdate_str} — {e}")
        return None


# Load existing progress if it exists
bio_file = "player_bios.csv"
if os.path.exists(bio_file):
    existing_bios = pd.read_csv(bio_file)
    processed_ids = set(existing_bios['id'].values)
    data = existing_bios.to_dict('records')
else:
    processed_ids = set()
    data = []

all_players = players.get_active_players()

for i, player in enumerate(all_players):
    player_id = player['id']
    full_name = player['full_name']

    if player_id in processed_ids:
        continue

    print(f"Processing {full_name}...")

    # Get basic info
    info = safe_request(lambda: commonplayerinfo.CommonPlayerInfo(player_id=player_id, headers=custom_headers))
    if info is None:
        print(f"Skipping {full_name} due to repeated errors.")
        continue

    info_df = info.get_data_frames()[0]
    if info_df.empty:
        print(f"No bio data for {full_name}")
        continue

    birthdate = info_df.at[0, 'BIRTHDATE']
    age = calculate_age(birthdate)

    # Get latest season stats
        # Get latest season stats
    career = safe_request(lambda: playercareerstats.PlayerCareerStats(player_id=player_id, headers=custom_headers))
    pts = ast = reb = stl = blk = None
    if career:
        stats_df = career.get_data_frames()[0]
        nba_stats = stats_df[stats_df['LEAGUE_ID'] == '00'].sort_values(by='SEASON_ID', ascending=False)
        if not nba_stats.empty:
            latest = nba_stats.iloc[0]
            games_played = latest['GP']
            if games_played and games_played > 0:
                pts = latest['PTS'] / games_played
                ast = latest['AST'] / games_played
                reb = latest['REB'] / games_played
                stl = latest['STL'] / games_played
                blk = latest['BLK'] / games_played


    # Get awards
    awards = safe_request(lambda: playerawards.PlayerAwards(player_id=player_id, headers=custom_headers))
    if awards:
        awards_df = awards.get_data_frames()[0]
        award_list = "; ".join(awards_df['DESCRIPTION'].tolist()) if not awards_df.empty else None
    else:
        award_list = None

    player_data = {
        'id': player_id,
        'full_name': full_name,
        'team': info_df.at[0, 'TEAM_NAME'] if 'TEAM_NAME' in info_df.columns else None,
        'position': info_df.at[0, 'POSITION'] if 'POSITION' in info_df.columns else None,
        'height': info_df.at[0, 'HEIGHT'] if 'HEIGHT' in info_df.columns else None,
        'weight': info_df.at[0, 'WEIGHT'] if 'WEIGHT' in info_df.columns else None,
        'college': info_df.at[0, 'COLLEGE'] if 'COLLEGE' in info_df.columns else None,
        'birthdate': birthdate,
        'age': age,
        'region': info_df.at[0, 'COUNTRY'] if 'COUNTRY' in info_df.columns else None,
        'average_points': pts,
        'average_assists': ast,
        'average_rebounds': reb,
        'average_steals': stl,
        'average_blocks': blk,
        'awards': award_list
    }

    data.append(player_data)
    processed_ids.add(player_id)

    print(f"{i+1}/{len(all_players)}: Saved bio for {full_name}")

    if len(data) % 10 == 0:
        print(f"{len(data)} players collected so far...")

    time.sleep(3)  # Respectful request spacing

# Final save
df2 = pd.DataFrame(data)
print("Collection complete. Data saved to player_bios.csv.")
# Out:
# Processing Precious Achiuwa...
# 1/572: Saved bio for Precious Achiuwa
# Processing Steven Adams...
# 2/572: Saved bio for Steven Adams
# Processing Bam Adebayo...
# 3/572: Saved bio for Bam Adebayo
# Processing Ochai Agbaji...
# 4/572: Saved bio for Ochai Agbaji
# Processing Santi Aldama...
# 5/572: Saved bio for Santi Aldama
# Processing Trey Alexander...
# 6/572: Saved bio for Trey Alexander
# Processing Nickeil Alexander-Walker...
# 7/572: Saved bio for Nickeil Alexander-Walker
# Processing Grayson Allen...
# 8/572: Saved bio for Grayson Allen
# Processing Jarrett Allen...
# 9/572: Saved bio for Jarrett Allen
# Processing Jose Alvarado...
# 10/572: Saved bio for Jose Alvarado
# 10 players collected so far...
# Processing Kyle Anderson...
# 11/572: Saved bio for Kyle Anderson
# Processing Giannis Antetokounmpo...
# 12/572: Saved bio for Giannis Antetokounmpo
# Processing Cole Anthony...
# 13/572: Saved bio for Cole Anthony
# Processing OG Anunoby...
# 14/572: Saved bio for OG Anunoby
# Processing Taran Armstrong...
# 15/572: Saved bio for Taran Armstrong
# Processing Deni Avdija...
# 16/572: Saved bio for Deni Avdija
# Processing Deandre Ayton...
# 17/572: Saved bio for Deandre Ayton
# Processing Marcus Bagley...
# 18/572: Saved bio for Marcus Bagley
# Processing Marvin Bagley III...
# 19/572: Saved bio for Marvin Bagley III
# Processing Patrick Baldwin Jr....
# 20/572: Saved bio for Patrick Baldwin Jr.
# 20 players collected so far...
# Processing LaMelo Ball...
# 21/572: Saved bio for LaMelo Ball
# Processing Lonzo Ball...
# 22/572: Saved bio for Lonzo Ball
# Processing Mo Bamba...
# 23/572: Saved bio for Mo Bamba
# Processing Paolo Banchero...
# 24/572: Saved bio for Paolo Banchero
# Processing Desmond Bane...
# 25/572: Saved bio for Desmond Bane
# Processing Dalano Banton...
# 26/572: Saved bio for Dalano Banton
# Processing Dominick Barlow...
# 27/572: Saved bio for Dominick Barlow
# Processing Harrison Barnes...
# 28/572: Saved bio for Harrison Barnes
# Processing Scottie Barnes...
# 29/572: Saved bio for Scottie Barnes
# Processing RJ Barrett...
# 30/572: Saved bio for RJ Barrett
# 30 players collected so far...
# Processing Charles Bassey...
# 31/572: Saved bio for Charles Bassey
# Processing Emoni Bates...
# 32/572: Saved bio for Emoni Bates
# Processing Jamison Battle...
# 33/572: Saved bio for Jamison Battle
# Processing Nicolas Batum...
# 34/572: Saved bio for Nicolas Batum
# Processing Damion Baugh...
# 35/572: Saved bio for Damion Baugh
# Processing Bradley Beal...
# 36/572: Saved bio for Bradley Beal
# Processing Malik Beasley...
# 37/572: Saved bio for Malik Beasley
# Processing MarJon Beauchamp...
# 38/572: Saved bio for MarJon Beauchamp
# Processing Reece Beekman...
# 39/572: Saved bio for Reece Beekman
# Processing Saddiq Bey...
# 40/572: Saved bio for Saddiq Bey
# 40 players collected so far...
# Processing Goga Bitadze...
# 41/572: Saved bio for Goga Bitadze
# Processing Bismack Biyombo...
# 42/572: Saved bio for Bismack Biyombo
# Processing Anthony Black...
# 43/572: Saved bio for Anthony Black
# Processing Bogdan Bogdanović...
# 44/572: Saved bio for Bogdan Bogdanović
# Processing Bol Bol...
# 45/572: Saved bio for Bol Bol
# Processing Adem Bona...
# 46/572: Saved bio for Adem Bona
# Processing Devin Booker...
# 47/572: Saved bio for Devin Booker
# Processing Brandon Boston...
# 48/572: Saved bio for Brandon Boston
# Processing Chris Boucher...
# 49/572: Saved bio for Chris Boucher
# Processing Jamaree Bouyea...
# 50/572: Saved bio for Jamaree Bouyea
# 50 players collected so far...
# Processing Tony Bradley...
# 51/572: Saved bio for Tony Bradley
# Processing Malaki Branham...
# 52/572: Saved bio for Malaki Branham
# Processing Christian Braun...
# 53/572: Saved bio for Christian Braun
# Processing Jalen Bridges...
# 54/572: Saved bio for Jalen Bridges
# Processing Mikal Bridges...
# 55/572: Saved bio for Mikal Bridges
# Processing Miles Bridges...
# 56/572: Saved bio for Miles Bridges
# Processing Oshae Brissett...
# 57/572: Saved bio for Oshae Brissett
# Processing Malcolm Brogdon...
# 58/572: Saved bio for Malcolm Brogdon
# Processing Dillon Brooks...
# 59/572: Saved bio for Dillon Brooks
# Processing Keion Brooks Jr....
# 60/572: Saved bio for Keion Brooks Jr.
# 60 players collected so far...
# Processing Bruce Brown...
# 61/572: Saved bio for Bruce Brown
# Processing Jaylen Brown...
# 62/572: Saved bio for Jaylen Brown
# Processing Kobe Brown...
# 63/572: Saved bio for Kobe Brown
# Processing Moses Brown...
# 64/572: Saved bio for Moses Brown
# Processing Jalen Brunson...
# 65/572: Saved bio for Jalen Brunson
# Processing Thomas Bryant...
# 66/572: Saved bio for Thomas Bryant
# Processing Kobe Bufkin...
# 67/572: Saved bio for Kobe Bufkin
# Processing Alec Burks...
# 68/572: Saved bio for Alec Burks
# Processing Jared Butler...
# 69/572: Saved bio for Jared Butler
# Processing Jimmy Butler III...
# 70/572: Saved bio for Jimmy Butler III
# 70 players collected so far...
# Processing Matas Buzelis...
# 71/572: Saved bio for Matas Buzelis
# Processing Jamal Cain...
# 72/572: Saved bio for Jamal Cain
# Processing Kentavious Caldwell-Pope...
# 73/572: Saved bio for Kentavious Caldwell-Pope
# Processing Toumani Camara...
# 74/572: Saved bio for Toumani Camara
# Processing Clint Capela...
# 75/572: Saved bio for Clint Capela
# Processing Branden Carlson...
# 76/572: Saved bio for Branden Carlson
# Processing Bub Carrington...
# 77/572: Saved bio for Bub Carrington
# Processing Devin Carter...
# 78/572: Saved bio for Devin Carter
# Processing Jevon Carter...
# 79/572: Saved bio for Jevon Carter
# Processing Wendell Carter Jr....
# 80/572: Saved bio for Wendell Carter Jr.
# 80 players collected so far...
# Processing D.J. Carton...
# 81/572: Saved bio for D.J. Carton
# Processing Alex Caruso...
# 82/572: Saved bio for Alex Caruso
# Processing Stephon Castle...
# 83/572: Saved bio for Stephon Castle
# Processing Colin Castleton...
# 84/572: Saved bio for Colin Castleton
# Processing Julian Champagnie...
# 85/572: Saved bio for Julian Champagnie
# Processing Justin Champagnie...
# 86/572: Saved bio for Justin Champagnie
# Processing Ulrich Chomche...
# 87/572: Saved bio for Ulrich Chomche
# Processing Cam Christie...
# 88/572: Saved bio for Cam Christie
# Processing Max Christie...
# 89/572: Saved bio for Max Christie
# Processing Josh Christopher...
# 90/572: Saved bio for Josh Christopher
# 90 players collected so far...
# Processing Sidy Cissoko...
# 91/572: Saved bio for Sidy Cissoko
# Processing Jaylen Clark...
# 92/572: Saved bio for Jaylen Clark
# Processing Brandon Clarke...
# 93/572: Saved bio for Brandon Clarke
# Processing Jordan Clarkson...
# 94/572: Saved bio for Jordan Clarkson
# Processing Nic Claxton...
# 95/572: Saved bio for Nic Claxton
# Processing Donovan Clingan...
# 96/572: Saved bio for Donovan Clingan
# Processing Noah Clowney...
# 97/572: Saved bio for Noah Clowney
# Processing Amir Coffey...
# 98/572: Saved bio for Amir Coffey
# Processing Isaiah Collier...
# 99/572: Saved bio for Isaiah Collier
# Processing John Collins...
# 100/572: Saved bio for John Collins
# 100 players collected so far...
# Processing Yuri Collins...
# 101/572: Saved bio for Yuri Collins
# Processing Zach Collins...
# 102/572: Saved bio for Zach Collins
# Processing Mike Conley...
# 103/572: Saved bio for Mike Conley
# Processing Pat Connaughton...
# 104/572: Saved bio for Pat Connaughton
# Processing Bilal Coulibaly...
# 105/572: Saved bio for Bilal Coulibaly
# Processing Ricky Council IV...
# 106/572: Saved bio for Ricky Council IV
# Processing Torrey Craig...
# 107/572: Saved bio for Torrey Craig
# Processing Isaiah Crawford...
# 108/572: Saved bio for Isaiah Crawford
# Processing Jae Crowder...
# 109/572: Saved bio for Jae Crowder
# Processing Cade Cunningham...
# 110/572: Saved bio for Cade Cunningham
# 110 players collected so far...
# Processing Seth Curry...
# 111/572: Saved bio for Seth Curry
# Processing Stephen Curry...
# 112/572: Saved bio for Stephen Curry
# Processing Pacome Dadiet...
# 113/572: Saved bio for Pacome Dadiet
# Processing Dyson Daniels...
# 114/572: Saved bio for Dyson Daniels
# Processing N'Faly Dante...
# 115/572: Saved bio for N'Faly Dante
# Processing Anthony Davis...
# 116/572: Saved bio for Anthony Davis
# Processing Johnny Davis...
# 117/572: Saved bio for Johnny Davis
# Processing JD Davison...
# 118/572: Saved bio for JD Davison
# Processing DeMar DeRozan...
# 119/572: Saved bio for DeMar DeRozan
# Processing RayJ Dennis...
# 120/572: Saved bio for RayJ Dennis
# 120 players collected so far...
# Processing Donte DiVincenzo...
# 121/572: Saved bio for Donte DiVincenzo
# Processing Moussa Diabaté...
# 122/572: Saved bio for Moussa Diabaté
# Processing Gradey Dick...
# 123/572: Saved bio for Gradey Dick
# Processing Ousmane Dieng...
# 124/572: Saved bio for Ousmane Dieng
# Processing Rob Dillingham...
# 125/572: Saved bio for Rob Dillingham
# Processing Spencer Dinwiddie...
# 126/572: Saved bio for Spencer Dinwiddie
# Processing Luka Dončić...
# 127/572: Saved bio for Luka Dončić
# Processing Luguentz Dort...
# 128/572: Saved bio for Luguentz Dort
# Processing Ayo Dosunmu...
# 129/572: Saved bio for Ayo Dosunmu
# Processing Jeff Dowtin Jr....
# 130/572: Saved bio for Jeff Dowtin Jr.
# 130 players collected so far...
# Processing PJ Dozier...
# 131/572: Saved bio for PJ Dozier
# Processing Andre Drummond...
# 132/572: Saved bio for Andre Drummond
# Processing Chris Duarte...
# 133/572: Saved bio for Chris Duarte
# Processing Alex Ducas...
# 134/572: Saved bio for Alex Ducas
# Processing David Duke Jr....
# 135/572: Saved bio for David Duke Jr.
# Processing Kris Dunn...
# 136/572: Saved bio for Kris Dunn
# Processing Ryan Dunn...
# 137/572: Saved bio for Ryan Dunn
# Processing Kevin Durant...
# 138/572: Saved bio for Kevin Durant
# Processing Jalen Duren...
# 139/572: Saved bio for Jalen Duren
# Processing Tari Eason...
# 140/572: Saved bio for Tari Eason
# 140 players collected so far...
# Processing Zach Edey...
# 141/572: Saved bio for Zach Edey
# Processing Anthony Edwards...
# 142/572: Saved bio for Anthony Edwards
# Processing Jesse Edwards...
# 143/572: Saved bio for Jesse Edwards
# Processing Justin Edwards...
# 144/572: Saved bio for Justin Edwards
# Processing Kessler Edwards...
# 145/572: Saved bio for Kessler Edwards
# Processing Keon Ellis...
# 146/572: Saved bio for Keon Ellis
# Processing Joel Embiid...
# 147/572: Saved bio for Joel Embiid
# Processing Tyson Etienne...
# 148/572: Saved bio for Tyson Etienne
# Processing Drew Eubanks...
# 149/572: Saved bio for Drew Eubanks
# Processing Tosan Evbuomwan...
# 150/572: Saved bio for Tosan Evbuomwan
# 150 players collected so far...
# Processing Danté Exum...
# 151/572: Saved bio for Danté Exum
# Processing Bruno Fernando...
# 152/572: Saved bio for Bruno Fernando
# Processing Kyle Filipowski...
# 153/572: Saved bio for Kyle Filipowski
# Processing Dorian Finney-Smith...
# 154/572: Saved bio for Dorian Finney-Smith
# Processing Adam Flagler...
# 155/572: Saved bio for Adam Flagler
# Processing Trentyn Flowers...
# 156/572: Saved bio for Trentyn Flowers
# Processing Malachi Flynn...
# 157/572: Saved bio for Malachi Flynn
# Processing Simone Fontecchio...
# 158/572: Saved bio for Simone Fontecchio
# Processing De'Aaron Fox...
# 159/572: Saved bio for De'Aaron Fox
# Processing Enrique Freeman...
# 160/572: Saved bio for Enrique Freeman
# 160 players collected so far...
# Processing Markelle Fultz...
# 161/572: Saved bio for Markelle Fultz
# Processing Johnny Furphy...
# 162/572: Saved bio for Johnny Furphy
# Processing Daniel Gafford...
# 163/572: Saved bio for Daniel Gafford
# Processing Darius Garland...
# 164/572: Saved bio for Darius Garland
# Processing Marcus Garrett...
# 165/572: Saved bio for Marcus Garrett
# Processing Luka Garza...
# 166/572: Saved bio for Luka Garza
# Processing Keyonte George...
# 167/572: Saved bio for Keyonte George
# Processing Kyshawn George...
# 168/572: Saved bio for Kyshawn George
# Processing Paul George...
# 169/572: Saved bio for Paul George
# Processing Taj Gibson...
# 170/572: Saved bio for Taj Gibson
# 170 players collected so far...
# Processing Josh Giddey...
# 171/572: Saved bio for Josh Giddey
# Processing Shai Gilgeous-Alexander...
# 172/572: Saved bio for Shai Gilgeous-Alexander
# Processing Anthony Gill...
# 173/572: Saved bio for Anthony Gill
# Processing Collin Gillespie...
# 174/572: Saved bio for Collin Gillespie
# Processing Rudy Gobert...
# 175/572: Saved bio for Rudy Gobert
# Processing Jordan Goodwin...
# 176/572: Saved bio for Jordan Goodwin
# Processing Aaron Gordon...
# 177/572: Saved bio for Aaron Gordon
# Processing Eric Gordon...
# 178/572: Saved bio for Eric Gordon
# Processing Jazian Gortman...
# 179/572: Saved bio for Jazian Gortman
# Processing Jerami Grant...
# 180/572: Saved bio for Jerami Grant
# 180 players collected so far...
# Processing AJ Green...
# 181/572: Saved bio for AJ Green
# Processing Draymond Green...
# 182/572: Saved bio for Draymond Green
# Processing Jalen Green...
# 183/572: Saved bio for Jalen Green
# Processing Javonte Green...
# 184/572: Saved bio for Javonte Green
# Processing Jeff Green...
# 185/572: Saved bio for Jeff Green
# Processing Josh Green...
# 186/572: Saved bio for Josh Green
# Processing Quentin Grimes...
# 187/572: Saved bio for Quentin Grimes
# Processing Mouhamed Gueye...
# 188/572: Saved bio for Mouhamed Gueye
# Processing Rui Hachimura...
# 189/572: Saved bio for Rui Hachimura
# Processing Tyrese Haliburton...
# 190/572: Saved bio for Tyrese Haliburton
# 190 players collected so far...
# Processing PJ Hall...
# 191/572: Saved bio for PJ Hall
# Processing Tim Hardaway Jr....
# 192/572: Saved bio for Tim Hardaway Jr.
# Processing James Harden...
# 193/572: Saved bio for James Harden
# Processing Jaden Hardy...
# 194/572: Saved bio for Jaden Hardy
# Processing Elijah Harkless...
# 195/572: Saved bio for Elijah Harkless
# Processing Ron Harper Jr....
# 196/572: Saved bio for Ron Harper Jr.
# Processing Gary Harris...
# 197/572: Saved bio for Gary Harris
# Processing Tobias Harris...
# 198/572: Saved bio for Tobias Harris
# Processing Josh Hart...
# 199/572: Saved bio for Josh Hart
# Processing Isaiah Hartenstein...
# 200/572: Saved bio for Isaiah Hartenstein
# 200 players collected so far...
# Processing Sam Hauser...
# 201/572: Saved bio for Sam Hauser
# Processing Jordan Hawkins...
# 202/572: Saved bio for Jordan Hawkins
# Processing Jaxson Hayes...
# 203/572: Saved bio for Jaxson Hayes
# Processing Killian Hayes...
# 204/572: Saved bio for Killian Hayes
# Processing Scoot Henderson...
# 205/572: Saved bio for Scoot Henderson
# Processing Taylor Hendricks...
# 206/572: Saved bio for Taylor Hendricks
# Processing Tyler Herro...
# 207/572: Saved bio for Tyler Herro
# Processing Buddy Hield...
# 208/572: Saved bio for Buddy Hield
# Processing Haywood Highsmith...
# 209/572: Saved bio for Haywood Highsmith
# Processing Aaron Holiday...
# 210/572: Saved bio for Aaron Holiday
# 210 players collected so far...
# Processing Jrue Holiday...
# 211/572: Saved bio for Jrue Holiday
# Processing Ronald Holland II...
# 212/572: Saved bio for Ronald Holland II
# Processing Richaun Holmes...
# 213/572: Saved bio for Richaun Holmes
# Processing DaRon Holmes II...
# 214/572: Saved bio for DaRon Holmes II
# Processing Chet Holmgren...
# 215/572: Saved bio for Chet Holmgren
# Processing Jalen Hood-Schifino...
# 216/572: Saved bio for Jalen Hood-Schifino
# Processing Al Horford...
# 217/572: Saved bio for Al Horford
# Processing Talen Horton-Tucker...
# 218/572: Saved bio for Talen Horton-Tucker
# Processing Caleb Houstan...
# 219/572: Saved bio for Caleb Houstan
# Processing Jett Howard...
# 220/572: Saved bio for Jett Howard
# 220 players collected so far...
# Processing Kevin Huerter...
# 221/572: Saved bio for Kevin Huerter
# Processing Jay Huff...
# 222/572: Saved bio for Jay Huff
# Processing Ariel Hukporti...
# 223/572: Saved bio for Ariel Hukporti
# Processing De'Andre Hunter...
# 224/572: Saved bio for De'Andre Hunter
# Processing Bones Hyland...
# 225/572: Saved bio for Bones Hyland
# Processing Oso Ighodaro...
# 226/572: Saved bio for Oso Ighodaro
# Processing Joe Ingles...
# 227/572: Saved bio for Joe Ingles
# Processing Brandon Ingram...
# 228/572: Saved bio for Brandon Ingram
# Processing Harrison Ingram...
# 229/572: Saved bio for Harrison Ingram
# Processing Kyrie Irving...
# 230/572: Saved bio for Kyrie Irving
# 230 players collected so far...
# Processing Jonathan Isaac...
# 231/572: Saved bio for Jonathan Isaac
# Processing Jaden Ivey...
# 232/572: Saved bio for Jaden Ivey
# Processing GG Jackson...
# 233/572: Saved bio for GG Jackson
# Processing Isaiah Jackson...
# 234/572: Saved bio for Isaiah Jackson
# Processing Quenton Jackson...
# 235/572: Saved bio for Quenton Jackson
# Processing Reggie Jackson...
# 236/572: Saved bio for Reggie Jackson
# Processing Andre Jackson Jr....
# 237/572: Saved bio for Andre Jackson Jr.
# Processing Jaren Jackson Jr....
# 238/572: Saved bio for Jaren Jackson Jr.
# Processing Trayce Jackson-Davis...
# 239/572: Saved bio for Trayce Jackson-Davis
# Processing Bronny James...
# 240/572: Saved bio for Bronny James
# 240 players collected so far...
# Processing LeBron James...
# 241/572: Saved bio for LeBron James
# Processing Jaime Jaquez Jr....
# 242/572: Saved bio for Jaime Jaquez Jr.
# Processing DaQuan Jeffries...
# 243/572: Saved bio for DaQuan Jeffries
# Processing Trey Jemison III...
# 244/572: Saved bio for Trey Jemison III
# Processing Daniss Jenkins...
# 245/572: Saved bio for Daniss Jenkins
# Processing Ty Jerome...
# 246/572: Saved bio for Ty Jerome
# Processing Isaiah Joe...
# 247/572: Saved bio for Isaiah Joe
# Processing AJ Johnson...
# 248/572: Saved bio for AJ Johnson
# Processing Cameron Johnson...
# 249/572: Saved bio for Cameron Johnson
# Processing Jalen Johnson...
# 250/572: Saved bio for Jalen Johnson
# 250 players collected so far...
# Processing James Johnson...
# 251/572: Saved bio for James Johnson
# Processing Keldon Johnson...
# 252/572: Saved bio for Keldon Johnson
# Processing Keon Johnson...
# 253/572: Saved bio for Keon Johnson
# Processing Keshad Johnson...
# 254/572: Saved bio for Keshad Johnson
# Processing Nikola Jokić...
# 255/572: Saved bio for Nikola Jokić
# Processing Colby Jones...
# 256/572: Saved bio for Colby Jones
# Processing Dillon Jones...
# 257/572: Saved bio for Dillon Jones
# Processing Herbert Jones...
# 258/572: Saved bio for Herbert Jones
# Processing Isaac Jones...
# 259/572: Saved bio for Isaac Jones
# Processing Kai Jones...
# 260/572: Saved bio for Kai Jones
# 260 players collected so far...
# Processing Mason Jones...
# 261/572: Saved bio for Mason Jones
# Processing Spencer Jones...
# 262/572: Saved bio for Spencer Jones
# Processing Tre Jones...
# 263/572: Saved bio for Tre Jones
# Processing Tyus Jones...
# 264/572: Saved bio for Tyus Jones
# Processing Derrick Jones Jr....
# 265/572: Saved bio for Derrick Jones Jr.
# Processing DeAndre Jordan...
# 266/572: Saved bio for DeAndre Jordan
# Processing Cory Joseph...
# 267/572: Saved bio for Cory Joseph
# Processing Nikola Jović...
# 268/572: Saved bio for Nikola Jović
# Processing Johnny Juzang...
# 269/572: Saved bio for Johnny Juzang
# Processing Yuki Kawamura...
# 270/572: Saved bio for Yuki Kawamura
# 270 players collected so far...
# Processing Kylor Kelley...
# 271/572: Saved bio for Kylor Kelley
# Processing Luke Kennard...
# 272/572: Saved bio for Luke Kennard
# Processing Walker Kessler...
# 273/572: Saved bio for Walker Kessler
# Processing Braxton Key...
# 274/572: Saved bio for Braxton Key
# Processing Corey Kispert...
# 275/572: Saved bio for Corey Kispert
# Processing Maxi Kleber...
# 276/572: Saved bio for Maxi Kleber
# Processing Bobi Klintman...
# 277/572: Saved bio for Bobi Klintman
# Processing Dalton Knecht...
# 278/572: Saved bio for Dalton Knecht
# Processing Kevin Knox II...
# 279/572: Saved bio for Kevin Knox II
# Processing Tyler Kolek...
# 280/572: Saved bio for Tyler Kolek
# 280 players collected so far...
# Processing Christian Koloko...
# 281/572: Saved bio for Christian Koloko
# Processing John Konchar...
# 282/572: Saved bio for John Konchar
# Processing Luke Kornet...
# 283/572: Saved bio for Luke Kornet
# Processing Vít Krejčí...
# 284/572: Saved bio for Vít Krejčí
# Processing Jonathan Kuminga...
# 285/572: Saved bio for Jonathan Kuminga
# Processing Kyle Kuzma...
# 286/572: Saved bio for Kyle Kuzma
# Processing Jake LaRavia...
# 287/572: Saved bio for Jake LaRavia
# Processing Zach LaVine...
# 288/572: Saved bio for Zach LaVine
# Processing Skal Labissiere...
# 289/572: Saved bio for Skal Labissiere
# Processing Jock Landale...
# 290/572: Saved bio for Jock Landale
# 290 players collected so far...
# Processing Pelle Larsson...
# 291/572: Saved bio for Pelle Larsson
# Processing A.J. Lawson...
# 292/572: Saved bio for A.J. Lawson
# Processing Caris LeVert...
# 293/572: Saved bio for Caris LeVert
# Processing Damion Lee...
# 294/572: Saved bio for Damion Lee
# Processing Alex Len...
# 295/572: Saved bio for Alex Len
# Processing Kawhi Leonard...
# 296/572: Saved bio for Kawhi Leonard
# Processing Malevy Leons...
# 297/572: Saved bio for Malevy Leons
# Processing Maxwell Lewis...
# 298/572: Saved bio for Maxwell Lewis
# Processing E.J. Liddell...
# 299/572: Saved bio for E.J. Liddell
# Processing Damian Lillard...
# 300/572: Saved bio for Damian Lillard
# 300 players collected so far...
# Processing Dereck Lively II...
# 301/572: Saved bio for Dereck Lively II
# Processing Chris Livingston...
# 302/572: Saved bio for Chris Livingston
# Processing Kevon Looney...
# 303/572: Saved bio for Kevon Looney
# Processing Brook Lopez...
# 304/572: Saved bio for Brook Lopez
# Processing Kevin Love...
# 305/572: Saved bio for Kevin Love
# Processing Kyle Lowry...
# 306/572: Saved bio for Kyle Lowry
# Processing Seth Lundy...
# 307/572: Saved bio for Seth Lundy
# Processing Trey Lyles...
# 308/572: Saved bio for Trey Lyles
# Processing Sandro Mamukelashvili...
# 309/572: Saved bio for Sandro Mamukelashvili
# Processing Terance Mann...
# 310/572: Saved bio for Terance Mann
# 310 players collected so far...
# Processing Tre Mann...
# 311/572: Saved bio for Tre Mann
# Processing Lauri Markkanen...
# 312/572: Saved bio for Lauri Markkanen
# Processing Naji Marshall...
# 313/572: Saved bio for Naji Marshall
# Processing Caleb Martin...
# 314/572: Saved bio for Caleb Martin
# Processing Cody Martin...
# 315/572: Saved bio for Cody Martin
# Processing Jaylen Martin...
# 316/572: Saved bio for Jaylen Martin
# Processing KJ Martin...
# 317/572: Saved bio for KJ Martin
# Processing Tyrese Martin...
# 318/572: Saved bio for Tyrese Martin
# Processing Garrison Mathews...
# 319/572: Saved bio for Garrison Mathews
# Processing Bennedict Mathurin...
# 320/572: Saved bio for Bennedict Mathurin
# 320 players collected so far...
# Processing Karlo Matković...
# 321/572: Saved bio for Karlo Matković
# Processing Tyrese Maxey...
# 322/572: Saved bio for Tyrese Maxey
# Processing Miles McBride...
# 323/572: Saved bio for Miles McBride
# Processing Jared McCain...
# 324/572: Saved bio for Jared McCain
# Processing Mac McClung...
# 325/572: Saved bio for Mac McClung
# Processing CJ McCollum...
# 326/572: Saved bio for CJ McCollum
# Processing T.J. McConnell...
# 327/572: Saved bio for T.J. McConnell
# Processing Kevin McCullar Jr....
# 328/572: Saved bio for Kevin McCullar Jr.
# Processing Jaden McDaniels...
# 329/572: Saved bio for Jaden McDaniels
# Processing Jalen McDaniels...
# 330/572: Saved bio for Jalen McDaniels
# 330 players collected so far...
# Processing Doug McDermott...
# 331/572: Saved bio for Doug McDermott
# Processing Bryce McGowens...
# 332/572: Saved bio for Bryce McGowens
# Processing Jordan McLaughlin...
# 333/572: Saved bio for Jordan McLaughlin
# Processing Jack McVeigh...
# 334/572: Saved bio for Jack McVeigh
# Processing De'Anthony Melton...
# 335/572: Saved bio for De'Anthony Melton
# Processing Sam Merrill...
# 336/572: Saved bio for Sam Merrill
# Processing Vasilije Micić...
# 337/572: Saved bio for Vasilije Micić
# Processing Khris Middleton...
# 338/572: Saved bio for Khris Middleton
# Processing Brandon Miller...
# 339/572: Saved bio for Brandon Miller
# Processing Emanuel Miller...
# 340/572: Saved bio for Emanuel Miller
# 340 players collected so far...
# Processing Jordan Miller...
# 341/572: Saved bio for Jordan Miller
# Processing Leonard Miller...
# 342/572: Saved bio for Leonard Miller
# Processing Patty Mills...
# 343/572: Saved bio for Patty Mills
# Processing Shake Milton...
# 344/572: Saved bio for Shake Milton
# Processing Justin Minaya...
# 345/572: Saved bio for Justin Minaya
# Processing Riley Minix...
# 346/572: Saved bio for Riley Minix
# Processing Josh Minott...
# 347/572: Saved bio for Josh Minott
# Processing Yves Missi...
# 348/572: Saved bio for Yves Missi
# Processing Ajay Mitchell...
# 349/572: Saved bio for Ajay Mitchell
# Processing Davion Mitchell...
# 350/572: Saved bio for Davion Mitchell
# 350 players collected so far...
# Processing Donovan Mitchell...
# 351/572: Saved bio for Donovan Mitchell
# Processing Evan Mobley...
# 352/572: Saved bio for Evan Mobley
# Processing Jonathan Mogbo...
# 353/572: Saved bio for Jonathan Mogbo
# Processing Malik Monk...
# 354/572: Saved bio for Malik Monk
# Processing Moses Moody...
# 355/572: Saved bio for Moses Moody
# Processing Tazé Moore...
# 356/572: Saved bio for Tazé Moore
# Processing Wendell Moore Jr....
# 357/572: Saved bio for Wendell Moore Jr.
# Processing Ja Morant...
# 358/572: Saved bio for Ja Morant
# Processing Markieff Morris...
# 359/572: Saved bio for Markieff Morris
# Processing Monté Morris...
# 360/572: Saved bio for Monté Morris
# 360 players collected so far...
# Processing Trey Murphy III...
# 361/572: Saved bio for Trey Murphy III
# Processing Dejounte Murray...
# 362/572: Saved bio for Dejounte Murray
# Processing Jamal Murray...
# 363/572: Saved bio for Jamal Murray
# Processing Keegan Murray...
# 364/572: Saved bio for Keegan Murray
# Processing Kris Murray...
# 365/572: Saved bio for Kris Murray
# Processing Svi Mykhailiuk...
# 366/572: Saved bio for Svi Mykhailiuk
# Processing Pete Nance...
# 367/572: Saved bio for Pete Nance
# Processing Larry Nance Jr....
# 368/572: Saved bio for Larry Nance Jr.
# Processing Andrew Nembhard...
# 369/572: Saved bio for Andrew Nembhard
# Processing Aaron Nesmith...
# 370/572: Saved bio for Aaron Nesmith
# 370 players collected so far...
# Processing Tristen Newton...
# 371/572: Saved bio for Tristen Newton
# Processing Georges Niang...
# 372/572: Saved bio for Georges Niang
# Processing Daishen Nix...
# 373/572: Saved bio for Daishen Nix
# Processing Zeke Nnaji...
# 374/572: Saved bio for Zeke Nnaji
# Processing Miles Norris...
# 375/572: Saved bio for Miles Norris
# Processing Jaylen Nowell...
# 376/572: Saved bio for Jaylen Nowell
# Processing Jusuf Nurkić...
# 377/572: Saved bio for Jusuf Nurkić
# Processing Royce O'Neale...
# 378/572: Saved bio for Royce O'Neale
# Processing Jahlil Okafor...
# 379/572: Saved bio for Jahlil Okafor
# Processing Chuma Okeke...
# 380/572: Saved bio for Chuma Okeke
# 380 players collected so far...
# Processing Josh Okogie...
# 381/572: Saved bio for Josh Okogie
# Processing Onyeka Okongwu...
# 382/572: Saved bio for Onyeka Okongwu
# Processing Isaac Okoro...
# 383/572: Saved bio for Isaac Okoro
# Processing Quincy Olivari...
# 384/572: Saved bio for Quincy Olivari
# Processing Kelly Olynyk...
# 385/572: Saved bio for Kelly Olynyk
# Processing Kelly Oubre Jr....
# 386/572: Saved bio for Kelly Oubre Jr.
# Processing Chris Paul...
# 387/572: Saved bio for Chris Paul
# Processing Cameron Payne...
# 388/572: Saved bio for Cameron Payne
# Processing Elfrid Payton...
# 389/572: Saved bio for Elfrid Payton
# Processing Gary Payton II...
# 390/572: Saved bio for Gary Payton II
# 390 players collected so far...
# Processing Drew Peterson...
# 391/572: Saved bio for Drew Peterson
# Processing Julian Phillips...
# 392/572: Saved bio for Julian Phillips
# Processing Jalen Pickett...
# 393/572: Saved bio for Jalen Pickett
# Processing Scotty Pippen Jr....
# 394/572: Saved bio for Scotty Pippen Jr.
# Processing Daeqwon Plowden...
# 395/572: Saved bio for Daeqwon Plowden
# Processing Mason Plumlee...
# 396/572: Saved bio for Mason Plumlee
# Processing Brandin Podziemski...
# 397/572: Saved bio for Brandin Podziemski
# Processing Jakob Poeltl...
# 398/572: Saved bio for Jakob Poeltl
# Processing Jordan Poole...
# 399/572: Saved bio for Jordan Poole
# Processing Craig Porter Jr....
# 400/572: Saved bio for Craig Porter Jr.
# 400 players collected so far...
# Processing Kevin Porter Jr....
# 401/572: Saved bio for Kevin Porter Jr.
# Processing Michael Porter Jr....
# 402/572: Saved bio for Michael Porter Jr.
# Processing Bobby Portis...
# 403/572: Saved bio for Bobby Portis
# Processing Kristaps Porziņģis...
# 404/572: Saved bio for Kristaps Porziņģis
# Processing Quinten Post...
# 405/572: Saved bio for Quinten Post
# Processing Micah Potter...
# 406/572: Saved bio for Micah Potter
# Processing Dwight Powell...
# 407/572: Saved bio for Dwight Powell
# Processing Norman Powell...
# 408/572: Saved bio for Norman Powell
# Processing Taurean Prince...
# 409/572: Saved bio for Taurean Prince
# Processing Payton Pritchard...
# 410/572: Saved bio for Payton Pritchard
# 410 players collected so far...
# Processing Olivier-Maxence Prosper...
# 411/572: Saved bio for Olivier-Maxence Prosper
# Processing Zyon Pullin...
# 412/572: Saved bio for Zyon Pullin
# Processing Trevelin Queen...
# 413/572: Saved bio for Trevelin Queen
# Processing Neemias Queta...
# 414/572: Saved bio for Neemias Queta
# Processing Immanuel Quickley...
# 415/572: Saved bio for Immanuel Quickley
# Processing Lester Quinones...
# 416/572: Saved bio for Lester Quinones
# Processing Julius Randle...
# 417/572: Saved bio for Julius Randle
# Processing Duop Reath...
# 418/572: Saved bio for Duop Reath
# Processing Austin Reaves...
# 419/572: Saved bio for Austin Reaves
# Processing Cam Reddish...
# 420/572: Saved bio for Cam Reddish
# 420 players collected so far...
# Processing Paul Reed...
# 421/572: Saved bio for Paul Reed
# Processing Alex Reese...
# 422/572: Saved bio for Alex Reese
# Processing Antonio Reeves...
# 423/572: Saved bio for Antonio Reeves
# Processing Naz Reid...
# 424/572: Saved bio for Naz Reid
# Processing Jared Rhoden...
# 425/572: Saved bio for Jared Rhoden
# Processing Nick Richards...
# 426/572: Saved bio for Nick Richards
# Processing Josh Richardson...
# 427/572: Saved bio for Josh Richardson
# Processing Zaccharie Risacher...
# 428/572: Saved bio for Zaccharie Risacher
# Processing Liam Robbins...
# 429/572: Saved bio for Liam Robbins
# Processing Duncan Robinson...
# 430/572: Saved bio for Duncan Robinson
# 430 players collected so far...
# Processing Mitchell Robinson...
# 431/572: Saved bio for Mitchell Robinson
# Processing Orlando Robinson...
# 432/572: Saved bio for Orlando Robinson
# Processing Jeremiah Robinson-Earl...
# 433/572: Saved bio for Jeremiah Robinson-Earl
# Processing David Roddy...
# 434/572: Saved bio for David Roddy
# Processing Ryan Rollins...
# 435/572: Saved bio for Ryan Rollins
# Processing Jackson Rowe...
# 436/572: Saved bio for Jackson Rowe
# Processing Terry Rozier...
# 437/572: Saved bio for Terry Rozier
# Processing Rayan Rupert...
# 438/572: Saved bio for Rayan Rupert
# Processing D'Angelo Russell...
# 439/572: Saved bio for D'Angelo Russell
# Processing Matt Ryan...
# 440/572: Saved bio for Matt Ryan
# 440 players collected so far...
# Processing Domantas Sabonis...
# 441/572: Saved bio for Domantas Sabonis
# Processing Tidjane Salaün...
# 442/572: Saved bio for Tidjane Salaün
# Processing Adama Sanogo...
# 443/572: Saved bio for Adama Sanogo
# Processing Gui Santos...
# 444/572: Saved bio for Gui Santos
# Processing Alex Sarr...
# 445/572: Saved bio for Alex Sarr
# Processing Marcus Sasser...
# 446/572: Saved bio for Marcus Sasser
# Processing Baylor Scheierman...
# 447/572: Saved bio for Baylor Scheierman
# Processing Dennis Schröder...
# 448/572: Saved bio for Dennis Schröder
# Processing Alperen Sengun...
# 449/572: Saved bio for Alperen Sengun
# Processing Brice Sensabaugh...
# 450/572: Saved bio for Brice Sensabaugh
# 450 players collected so far...
# Processing Collin Sexton...
# 451/572: Saved bio for Collin Sexton
# Processing Landry Shamet...
# 452/572: Saved bio for Landry Shamet
# Processing Terrence Shannon Jr....
# 453/572: Saved bio for Terrence Shannon Jr.
# Processing Day'Ron Sharpe...
# 454/572: Saved bio for Day'Ron Sharpe
# Processing Shaedon Sharpe...
# 455/572: Saved bio for Shaedon Sharpe
# Processing Jamal Shead...
# 456/572: Saved bio for Jamal Shead
# Processing Ben Sheppard...
# 457/572: Saved bio for Ben Sheppard
# Processing Reed Sheppard...
# 458/572: Saved bio for Reed Sheppard
# Processing Pascal Siakam...
# 459/572: Saved bio for Pascal Siakam
# Processing Ben Simmons...
# 460/572: Saved bio for Ben Simmons
# 460 players collected so far...
# Processing Anfernee Simons...
# 461/572: Saved bio for Anfernee Simons
# Processing KJ Simpson...
# 462/572: Saved bio for KJ Simpson
# Processing Jericho Sims...
# 463/572: Saved bio for Jericho Sims
# Processing Marcus Smart...
# 464/572: Saved bio for Marcus Smart
# Processing Dru Smith...
# 465/572: Saved bio for Dru Smith
# Processing Jalen Smith...
# 466/572: Saved bio for Jalen Smith
# Processing Tolu Smith...
# 467/572: Saved bio for Tolu Smith
# Processing Tyler Smith...
# 468/572: Saved bio for Tyler Smith
# Processing Jabari Smith Jr....
# 469/572: Saved bio for Jabari Smith Jr.
# Processing Nick Smith Jr....
# 470/572: Saved bio for Nick Smith Jr.
# 470 players collected so far...
# Processing Jeremy Sochan...
# 471/572: Saved bio for Jeremy Sochan
# Processing Cam Spencer...
# 472/572: Saved bio for Cam Spencer
# Processing Pat Spencer...
# 473/572: Saved bio for Pat Spencer
# Processing Jaden Springer...
# 474/572: Saved bio for Jaden Springer
# Processing Isaiah Stevens...
# 475/572: Saved bio for Isaiah Stevens
# Processing Lamar Stevens...
# 476/572: Saved bio for Lamar Stevens
# Processing Isaiah Stewart...
# 477/572: Saved bio for Isaiah Stewart
# Processing Julian Strawther...
# 478/572: Saved bio for Julian Strawther
# Processing Max Strus...
# 479/572: Saved bio for Max Strus
# Processing Jalen Suggs...
# 480/572: Saved bio for Jalen Suggs
# 480 players collected so far...
# Processing Cole Swider...
# 481/572: Saved bio for Cole Swider
# Processing Jae'Sean Tate...
# 482/572: Saved bio for Jae'Sean Tate
# Processing Jayson Tatum...
# 483/572: Saved bio for Jayson Tatum
# Processing Terry Taylor...
# 484/572: Saved bio for Terry Taylor
# Processing Garrett Temple...
# 485/572: Saved bio for Garrett Temple
# Processing Dalen Terry...
# 486/572: Saved bio for Dalen Terry
# Processing Daniel Theis...
# 487/572: Saved bio for Daniel Theis
# Processing Cam Thomas...
# 488/572: Saved bio for Cam Thomas
# Processing Amen Thompson...
# 489/572: Saved bio for Amen Thompson
# Processing Ausar Thompson...
# 490/572: Saved bio for Ausar Thompson
# 490 players collected so far...
# Processing Ethan Thompson...
# 491/572: Saved bio for Ethan Thompson
# Processing Klay Thompson...
# 492/572: Saved bio for Klay Thompson
# Processing Tristan Thompson...
# 493/572: Saved bio for Tristan Thompson
# Processing JT Thor...
# 494/572: Saved bio for JT Thor
# Processing Matisse Thybulle...
# 495/572: Saved bio for Matisse Thybulle
# Processing Xavier Tillman...
# 496/572: Saved bio for Xavier Tillman
# Processing Drew Timme...
# 497/572: Saved bio for Drew Timme
# Processing Nae'Qwan Tomlin...
# 498/572: Saved bio for Nae'Qwan Tomlin
# Processing Nikola Topić...
# 499/572: Saved bio for Nikola Topić
# Processing Jacob Toppin...
# 500/572: Saved bio for Jacob Toppin
# 500 players collected so far...
# Processing Obi Toppin...
# 501/572: Saved bio for Obi Toppin
# Processing Karl-Anthony Towns...
# 502/572: Saved bio for Karl-Anthony Towns
# Processing Armel Traoré...
# 503/572: Saved bio for Armel Traoré
# Processing Luke Travers...
# 504/572: Saved bio for Luke Travers
# Processing Gary Trent Jr....
# 505/572: Saved bio for Gary Trent Jr.
# Processing Oscar Tshiebwe...
# 506/572: Saved bio for Oscar Tshiebwe
# Processing P.J. Tucker...
# 507/572: Saved bio for P.J. Tucker
# Processing Myles Turner...
# 508/572: Saved bio for Myles Turner
# Processing Hunter Tyson...
# 509/572: Saved bio for Hunter Tyson
# Processing Jaylon Tyson...
# 510/572: Saved bio for Jaylon Tyson
# 510 players collected so far...
# Processing Stanley Umude...
# 511/572: Saved bio for Stanley Umude
# Processing Jonas Valančiūnas...
# 512/572: Saved bio for Jonas Valančiūnas
# Processing Fred VanVleet...
# 513/572: Saved bio for Fred VanVleet
# Processing Jarred Vanderbilt...
# 514/572: Saved bio for Jarred Vanderbilt
# Processing Devin Vassell...
# 515/572: Saved bio for Devin Vassell
# Processing Gabe Vincent...
# 516/572: Saved bio for Gabe Vincent
# Processing Tristan Vukcevic...
# 517/572: Saved bio for Tristan Vukcevic
# Processing Nikola Vučević...
# 518/572: Saved bio for Nikola Vučević
# Processing Dean Wade...
# 519/572: Saved bio for Dean Wade
# Processing Franz Wagner...
# 520/572: Saved bio for Franz Wagner
# 520 players collected so far...
# Processing Moritz Wagner...
# 521/572: Saved bio for Moritz Wagner
# Processing Jabari Walker...
# 522/572: Saved bio for Jabari Walker
# Processing Jarace Walker...
# 523/572: Saved bio for Jarace Walker
# Processing Lonnie Walker IV...
# 524/572: Saved bio for Lonnie Walker IV
# Processing Cason Wallace...
# 525/572: Saved bio for Cason Wallace
# Processing Keaton Wallace...
# 526/572: Saved bio for Keaton Wallace
# Processing Jordan Walsh...
# 527/572: Saved bio for Jordan Walsh
# Processing Ja'Kobe Walter...
# 528/572: Saved bio for Ja'Kobe Walter
# Processing Kel'el Ware...
# 529/572: Saved bio for Kel'el Ware
# Processing P.J. Washington...
# 530/572: Saved bio for P.J. Washington
# 530 players collected so far...
# Processing TyTy Washington Jr....
# 531/572: Saved bio for TyTy Washington Jr.
# Processing Lindy Waters III...
# 532/572: Saved bio for Lindy Waters III
# Processing Trendon Watford...
# 533/572: Saved bio for Trendon Watford
# Processing Anton Watson...
# 534/572: Saved bio for Anton Watson
# Processing Peyton Watson...
# 535/572: Saved bio for Peyton Watson
# Processing Jaylen Wells...
# 536/572: Saved bio for Jaylen Wells
# Processing Victor Wembanyama...
# 537/572: Saved bio for Victor Wembanyama
# Processing Blake Wesley...
# 538/572: Saved bio for Blake Wesley
# Processing Russell Westbrook...
# 539/572: Saved bio for Russell Westbrook
# Processing Phillip Wheeler...
# 540/572: Saved bio for Phillip Wheeler
# 540 players collected so far...
# Processing Coby White...
# 541/572: Saved bio for Coby White
# Processing Derrick White...
# 542/572: Saved bio for Derrick White
# Processing Dariq Whitehead...
# 543/572: Saved bio for Dariq Whitehead
# Processing Cam Whitmore...
# 544/572: Saved bio for Cam Whitmore
# Processing Aaron Wiggins...
# 545/572: Saved bio for Aaron Wiggins
# Processing Andrew Wiggins...
# 546/572: Saved bio for Andrew Wiggins
# Processing Alondes Williams...
# 547/572: Saved bio for Alondes Williams
# Processing Brandon Williams...
# 548/572: Saved bio for Brandon Williams
# Processing Cody Williams...
# 549/572: Saved bio for Cody Williams
# Processing Grant Williams...
# 550/572: Saved bio for Grant Williams
# 550 players collected so far...
# Processing Jalen Williams...
# 551/572: Saved bio for Jalen Williams
# Processing Jaylin Williams...
# 552/572: Saved bio for Jaylin Williams
# Processing Kenrich Williams...
# 553/572: Saved bio for Kenrich Williams
# Processing Mark Williams...
# 554/572: Saved bio for Mark Williams
# Processing Nate Williams...
# 555/572: Saved bio for Nate Williams
# Processing Patrick Williams...
# 556/572: Saved bio for Patrick Williams
# Processing Ziaire Williams...
# 557/572: Saved bio for Ziaire Williams
# Processing Robert Williams III...
# 558/572: Saved bio for Robert Williams III
# Processing Vince Williams Jr....
# 559/572: Saved bio for Vince Williams Jr.
# Processing Zion Williamson...
# 560/572: Saved bio for Zion Williamson
# 560 players collected so far...
# Processing Jalen Wilson...
# 561/572: Saved bio for Jalen Wilson
# Processing James Wiseman...
# 562/572: Saved bio for James Wiseman
# Processing Isaiah Wong...
# 563/572: Saved bio for Isaiah Wong
# Processing Delon Wright...
# 564/572: Saved bio for Delon Wright
# Processing Guerschon Yabusele...
# 565/572: Saved bio for Guerschon Yabusele
# Processing Cui Yongxi...
# 566/572: Saved bio for Cui Yongxi
# Processing Jahmir Young...
# 567/572: Saved bio for Jahmir Young
# Processing Trae Young...
# 568/572: Saved bio for Trae Young
# Processing Ivica Zubac...
# 569/572: Saved bio for Ivica Zubac
# Processing Tristan da Silva...
# 570/572: Saved bio for Tristan da Silva
# 570 players collected so far...
# Processing Vlatko Čančar...
# 571/572: Saved bio for Vlatko Čančar
# Processing Dario Šarić...
# 572/572: Saved bio for Dario Šarić
# Collection complete. Data saved to player_bios.csv.

# %%
df2.to_csv("/Users/michaelluo/Desktop/DSC-Wizzrad/playerdata.csv")
#df2 = df2.drop(["id", "college", "birthdate"], axis = 1)
def height_to_cm(height):
    feet, inches = height.split('-')  # Split the height string into feet and inches
    feet = int(feet)  # Convert feet to integer
    inches = int(inches)  # Convert inches to integer
    cm = feet * 30.48 + inches * 2.54  # Convert to cm
    return cm

# Apply the function to the 'height' column and create a new 'height_cm' column
df2['height'] = df2['height'].apply(height_to_cm)
df2["height"]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 df2
#       2 df2.to_csv("/Users/michaelluo/Desktop/DSC-Wizzrad/playerdata.csv")
#       3 #df2 = df2.drop(["id", "college", "birthdate"], axis = 1)
#
# NameError: name 'df2' is not defined

# %%
df2 =pd.read_csv("/Users/michaelluo/Desktop/DSC-Wizzrad/playerdata.csv")
df2.dtypes
# Out:
# Unnamed: 0            int64
# full_name            object
# team                 object
# position             object
# height              float64
# weight              float64
# age                   int64
# region               object
# average_points      float64
# average_assists     float64
# average_rebounds    float64
# average_steals      float64
# average_blocks      float64
# awards               object
# conference           object
# dtype: object

# %%
import pandas as pd
from sklearn.tree import DecisionTreeClassifier, _tree

# === Step 1: Load and Prepare Your Data ===

# Load your dataset
df = pd.read_csv("/Users/michaelluo/Desktop/DSC-Wizzrad/playerdata.csv")

# Fix the 'awards' column: turn it into a numeric count
df['awards'] = df['awards'].fillna('')
df['awards_count'] = df['awards'].apply(lambda x: len(x.split(',')) if x else 0)

# Select numeric features
numeric_features = [
    'age', 'height', 'weight',
    'average_points', 'average_assists',
    'average_rebounds', 'average_steals', 'average_blocks',
    'awards_count'
]

# One-hot encode categorical features
categorical_features = pd.get_dummies(df[['position', 'team', 'region']])

# Combine all features
X = pd.concat([df[numeric_features], categorical_features], axis=1)

# Target: player name
y = df['full_name']

# === Step 2: Train Decision Tree Classifier ===

clf = DecisionTreeClassifier(max_depth=10)
clf.fit(X, y)

# === Step 3: Interactive Game ===

def ask_question(question: str):
    while True:
        answer = input(f"{question} (y/n): ").strip().lower()
        if answer in ['y', 'yes']:
            return True
        elif answer in ['n', 'no']:
            return False
        else:
            print("Please answer with 'y' or 'n'.")

def traverse_tree(clf, feature_names):
    tree = clf.tree_
    feature_name = [
        feature_names[i] if i != _tree.TREE_UNDEFINED else "undefined!"
        for i in tree.feature
    ]

    def clean_question(name, threshold):
        # Handle binary one-hot columns
        if '_Cavaliers' in name or '_Lakers' in name or '_Warriors' in name or '_team_' in name:
            team = name.split('_')[-1]
            return f"Is the player on the {team}?"
        if name.startswith("position_"):
            pos = name.split('_')[1]
            return f"Is the player's position {pos}?"
        if name.startswith("region_"):
            region = name.split('_')[1]
            return f"Is the player from the {region} region?"
        if threshold == 0.5:
            return f"Does the player have '{name.replace('_', ' ')}'?"
        return f"Is the player's '{name.replace('_', ' ')}' > {round(threshold, 2)}?"

    def recurse(node):
        if tree.feature[node] != _tree.TREE_UNDEFINED:
            name = feature_name[node]
            threshold = tree.threshold[node]
            question = clean_question(name, threshold)
            answer = ask_question(question)

            if answer:
                return recurse(tree.children_right[node])
            else:
                return recurse(tree.children_left[node])
        else:
            values = tree.value[node][0]
            best_guess_index = values.argmax()
            guess = clf.classes_[best_guess_index]
            return guess

    return recurse(0)


# === Step 4: Play the Game ===

print("🔮 Think of an active NBA player in your mind...")
input("Press Enter when you're ready!\n")

guess = traverse_tree(clf, X.columns)
print(f"\n🏀 My guess is... **{guess}**!")
# Out:
# 🔮 Think of an active NBA player in your mind...
#
# 🏀 My guess is... **A.J. Lawson**!

# %%
# Define which teams are in which conference
east_teams = [
    'Celtics', 'Nets', 'Knicks', '76ers', 'Raptors',
    'Bulls', 'Cavaliers', 'Pistons', 'Pacers', 'Bucks',
    'Heat', 'Hawks', 'Hornets', 'Magic', 'Wizards'
]

# Create new column 'conference' based on the team
df2['conference'] = df2['team'].apply(lambda team: 'East' if team in east_teams else 'West')
df2.to_csv("/Users/michaelluo/Desktop/DSC-Wizzrad/playerdata.csv")
df2["position"].unique()
# Out:
# array(['Forward', 'Center', 'Center-Forward', 'Guard', 'Forward-Center',
#        'Forward-Guard', 'Guard-Forward'], dtype=object)

# %%
import pandas as pd
import numpy as np

# === Helper Functions ===
def ask_question(question: str):
    while True:
        ans = input(f"{question} (y/n): ").strip().lower()
        if ans in ['y', 'yes']:
            return True
        elif ans in ['n', 'no']:
            return False
        else:
            print("Please answer with 'y' or 'n'.")

def cm_to_inches(cm):
    inches = cm / 2.54
    feet = int(inches // 12)
    inches_remainder = round(inches % 12)
    return f"{feet}'{inches_remainder}\""

def clean_position(pos):
    pos = str(pos).lower()
    if 'guard' in pos and 'forward' in pos:
        return 'G-F'
    if ('forward' in pos and 'center' in pos) or ('center' in pos and 'forward' in pos):
        return 'F-C'
    if 'forward' in pos:
        return 'F'
    if 'center' in pos:
        return 'C'
    if 'guard' in pos:
        return 'G'
    return 'Unknown'

# === Load and Clean the Dataset ===
print("🔮 Think of an active NBA player from the dataset...")
print("Let's narrow down who your player is!")

df = pd.read_csv("/Users/michaelluo/Desktop/DSC-Wizzrad/playerdata.csv")

# Fix awards
df['awards'] = df['awards'].fillna('')
df['awards_count'] = df['awards'].apply(lambda x: len(x.split(',')) if x else 0)

# Standardize positions
df['position'] = df['position'].apply(clean_position)

# === Ask if player is in the East Conference first ===
is_east_conference = ask_question("Is your player in the Eastern Conference?")
chosen_conference = "East" if is_east_conference else "West"

# Filter the data by selected conference
players = df[df['conference'] == chosen_conference].copy()

# Binary search algorithm
def find_player(players_df):
    current_players = players_df.copy()
    
    # Track the number of questions asked
    questions_asked = 0
    
    # Continue asking questions until we narrow down to one player
    while len(current_players) > 1:
        questions_asked += 1
        
        # Display how many players left (for debugging)
        print(f"[Debug] {len(current_players)} players remaining.")
        
        # If we're down to a few players, directly confirm with names
        if len(current_players) <= 5:
            # Ask directly about specific players
            for _, player_row in current_players.iterrows():
                player_name = player_row['full_name']
                is_player = ask_question(f"Is your player {player_name}?")
                if is_player:
                    return player_name
            
            # If we get here, something went wrong
            return "Player not found. There might be an error in the dataset."
        
        # Find the column that most evenly divides the remaining players
        best_column = None
        best_threshold = None
        best_balance = float('inf')  # Lower is better (we want 50/50 split)
        
        # First try team-based questions (very effective)
        teams = current_players['team'].unique()
        if len(teams) > 1:
            for team in teams:
                team_count = (current_players['team'] == team).sum()
                non_team_count = len(current_players) - team_count
                balance = abs(team_count - non_team_count)
                
                if balance < best_balance:
                    best_balance = balance
                    best_column = 'team'
                    best_threshold = team
        
        # Handle position questions differently to be more specific
        position_groups = {
            'pure_guard': current_players['position'] == 'G',
            'pure_forward': current_players['position'] == 'F',
            'pure_center': current_players['position'] == 'C',
            'guard_forward': current_players['position'] == 'G-F',
            'forward_center': current_players['position'] == 'F-C'
        }
        
        for pos_type, pos_filter in position_groups.items():
            pos_count = pos_filter.sum()
            non_pos_count = len(current_players) - pos_count
            balance = abs(pos_count - non_pos_count)
            
            if balance < best_balance and pos_count > 0:
                best_balance = balance
                best_column = 'position_specific'
                best_threshold = pos_type
        
        # Try awards
        has_awards = current_players['awards_count'] > 0
        award_count = has_awards.sum()
        no_award_count = len(current_players) - award_count
        award_balance = abs(award_count - no_award_count)
        
        if award_balance < best_balance:
            best_balance = award_balance
            best_column = 'awards'
            best_threshold = None
        
        # Try numeric columns
        numeric_cols = ['age', 'height', 'weight', 'average_points', 'average_assists', 
                       'average_rebounds', 'average_steals', 'average_blocks']
        
        for col in numeric_cols:
            values = sorted(current_players[col].unique())
            if len(values) > 1:
                # Try different threshold values for better split
                for i in range(len(values) - 1):
                    threshold = (values[i] + values[i + 1]) / 2
                    
                    left_count = (current_players[col] <= threshold).sum()
                    right_count = len(current_players) - left_count
                    balance = abs(left_count - right_count)
                    
                    if balance < best_balance:
                        best_balance = balance
                        best_column = col
                        best_threshold = threshold
        
        # Ask the question based on the best dividing attribute
        if best_column == 'team':
            answer = ask_question(f"Is your player on the {best_threshold}?")
            if answer:
                current_players = current_players[current_players['team'] == best_threshold]
            else:
                current_players = current_players[current_players['team'] != best_threshold]
        
        elif best_column == 'position_specific':
            if best_threshold == 'pure_guard':
                answer = ask_question(f"Is your player strictly a Guard (G), not a Guard-Forward hybrid?")
                if answer:
                    current_players = current_players[current_players['position'] == 'G']
                else:
                    current_players = current_players[current_players['position'] != 'G']
            elif best_threshold == 'pure_forward':
                answer = ask_question(f"Is your player strictly a Forward (F), not a hybrid position?")
                if answer:
                    current_players = current_players[current_players['position'] == 'F']
                else:
                    current_players = current_players[current_players['position'] != 'F']
            elif best_threshold == 'pure_center':
                answer = ask_question(f"Is your player strictly a Center (C), not a Forward-Center hybrid?")
                if answer:
                    current_players = current_players[current_players['position'] == 'C']
                else:
                    current_players = current_players[current_players['position'] != 'C']
            elif best_threshold == 'guard_forward':
                answer = ask_question(f"Is your player a Guard-Forward (G-F) hybrid?")
                if answer:
                    current_players = current_players[current_players['position'] == 'G-F']
                else:
                    current_players = current_players[current_players['position'] != 'G-F']
            elif best_threshold == 'forward_center':
                answer = ask_question(f"Is your player a Forward-Center (F-C) hybrid?")
                if answer:
                    current_players = current_players[current_players['position'] == 'F-C']
                else:
                    current_players = current_players[current_players['position'] != 'F-C']
        
        elif best_column == 'awards':
            answer = ask_question(f"Has your player received any awards?")
            if answer:
                current_players = current_players[current_players['awards_count'] > 0]
            else:
                current_players = current_players[current_players['awards_count'] == 0]
        
        elif best_column == 'age':
            answer = ask_question(f"Is your player older than {int(best_threshold)} years?")
            if answer:
                current_players = current_players[current_players[best_column] > best_threshold]
            else:
                current_players = current_players[current_players[best_column] <= best_threshold]
        
        elif best_column == 'height':
            answer = ask_question(f"Is your player taller than {cm_to_inches(best_threshold)}?")
            if answer:
                current_players = current_players[current_players[best_column] > best_threshold]
            else:
                current_players = current_players[current_players[best_column] <= best_threshold]
        
        elif best_column == 'weight':
            answer = ask_question(f"Is your player heavier than {int(best_threshold)} lbs?")
            if answer:
                current_players = current_players[current_players[best_column] > best_threshold]
            else:
                current_players = current_players[current_players[best_column] <= best_threshold]
        
        elif best_column in ['average_points', 'average_assists', 'average_rebounds', 'average_steals', 'average_blocks']:
            stat_name = best_column.replace('average_', '')
            answer = ask_question(f"Does your player average more than {best_threshold:.1f} {stat_name}?")
            if answer:
                current_players = current_players[current_players[best_column] > best_threshold]
            else:
                current_players = current_players[current_players[best_column] <= best_threshold]
        
        # Fallback if no good question found
        else:
            # Just ask directly about subset of players
            half_index = len(current_players) // 2
            first_half = current_players.iloc[:half_index]
            player_names = ', '.join(first_half['full_name'].values)
            
            answer = ask_question(f"Is your player one of these: {player_names}?")
            if answer:
                current_players = first_half
            else:
                current_players = current_players.iloc[half_index:]
    
    # Return the only player left
    if len(current_players) == 1:
        player_name = current_players['full_name'].iloc[0]
        # Final confirmation
        confirmation = ask_question(f"Just to confirm: Is your player {player_name}?")
        if confirmation:
            return player_name
        else:
            print("Hmm, something seems off. Let me try a different approach.")
            # If user says no, then something went wrong - let's restart with original dataset
            # But only include players from the chosen conference
            return find_player_with_direct_questions(players_df)
    else:
        # This should never happen, but just in case
        return "Could not determine the player. Something went wrong."

def find_player_with_direct_questions(players_df):
    """Fallback function that just asks directly about each player."""
    print("\n⚠️ Using backup approach to find your player...")
    
    for team in sorted(players_df['team'].unique()):
        team_players = players_df[players_df['team'] == team]
        if ask_question(f"Is your player on the {team}?"):
            print(f"Great! Your player is on the {team}.")
            for _, player in team_players.iterrows():
                player_name = player['full_name']
                if ask_question(f"Is your player {player_name}?"):
                    return player_name
            
            # If we get here, the player wasn't found
            return "Player not found in the dataset for the selected team."
    
    return "Player not found in the dataset."

# Run the game
guess = find_player(players)
print(f"\n🏀 My guess is... **{guess}**!")
print("Thanks for playing!")
# Out:
# 🔮 Think of an active NBA player from the dataset...
# Let's narrow down who your player is!
# [Debug] 268 players remaining.
# [Debug] 132 players remaining.
# [Debug] 66 players remaining.
# [Debug] 33 players remaining.
# [Debug] 17 players remaining.
# [Debug] 9 players remaining.
# [Debug] 5 players remaining.
#
# 🏀 My guess is... **Saddiq Bey**!
# Thanks for playing!

# %%
df2.dtypes
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 df2.dtypes
#
# NameError: name 'df2' is not defined
